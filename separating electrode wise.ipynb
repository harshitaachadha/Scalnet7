# %% [markdown]
# # **Separating data electrode wise**

# %%
from google.colab import drive
drive.mount('/content/drive')
from os import listdir
from os.path import isfile, join

Image_names = [f for f in listdir('/content/drive/MyDrive/python_code_major/image_dataset') ]
print(Image_names)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['per81_norm_9_9.png', 'per81_norm_9_10.png', 'per81_norm_9_11.png', 'per81_norm_9_12.png', 'per81_norm_9_13.png', 'per81_norm_9_14.png', 'per81_norm_10_1.png', 'per81_norm_10_2.png', 'per81_norm_10_3.png', 'per81_norm_10_4.png', 'per81_norm_10_5.png', 'per81_norm_10_6.png', 'per81_norm_10_7.png', 'per81_norm_10_8.png', 'per81_norm_10_9.png', 'per81_norm_10_10.png', 'per81_norm_10_11.png', 'per81_norm_10_12.png', 'per81_norm_10_13.png', 'per81_norm_10_14.png', 'per81_norm_11_1.png', 'per81_norm_11_2.png', 'per81_norm_11_3.png', 'per81_norm_11_4.png', 'per81_norm_11_5.png', 'per81_norm_11_6.png', 'per81_norm_11_7.png', 'per81_norm_11_8.png', 'per81_norm_11_9.png', 'per81_norm_11_10.png', 'per81_norm_11_11.png', 'per81_norm_11_12.png', 'per81_norm_11_13.png', 'per81_norm_11_14.png', 'per81_norm_12_1.png', 'per81_norm_12_2.png', 'per81_norm_12_3.png', 'per81_norm_12_4.png', 'per81_norm_12_5.png', 'per81_norm_12_6.png', 'per81_norm_12_7.png', 'per81_norm_12_8.png', 'per81_norm_12_9.png', 'per81_norm_12_10.png', 'per81_norm_12_11.png', 'per81_norm_12_12.png', 'per81_norm_12_13.png', 'per81_norm_12_14.png', 'per81_norm_13_1.png', 'per81_norm_13_2.png', 'per81_norm_13_3.png', 'per81_norm_13_4.png', 'per81_norm_13_5.png', 'per81_norm_13_6.png', 'per81_norm_13_7.png', 'per81_norm_13_8.png', 'per81_norm_13_9.png', 'per81_norm_13_10.png', 'per81_norm_13_11.png', 'per81_norm_13_12.png', 'per81_norm_13_13.png', 'per81_norm_13_14.png', 'per81_norm_14_1.png', 'per81_norm_14_2.png', 'per81_norm_14_3.png', 'per81_norm_14_4.png', 'per81_norm_14_5.png', 'per81_norm_14_6.png', 'per81_norm_14_7.png', 'per81_norm_14_8.png', 'per81_norm_14_9.png', 'per81_norm_14_10.png', 'per81_norm_14_11.png', 'per81_norm_14_12.png', 'per81_norm_14_13.png', 'per81_norm_14_14.png', 'per81_norm_15_1.png', 'per81_norm_15_2.png', 'per81_norm_15_3.png', 'per81_norm_15_4.png', 'per81_norm_15_5.png', 'per81_norm_15_6.png', 'per81_norm_15_7.png', 'per81_norm_15_8.png', 'per81_norm_15_9.png', 'per81_norm_15_10.png', 'per81_norm_15_11.png', 'per81_norm_15_12.png', 'per81_norm_15_13.png', 'per81_norm_15_14.png', 'per81_norm_16_1.png', 'per81_norm_16_2.png', 'per81_norm_16_3.png', 'per81_norm_16_4.png', 'per81_norm_16_5.png', 'per81_norm_16_6.png', 'per81_norm_16_7.png', 'per81_norm_16_8.png', 'per81_norm_16_9.png', 'per81_norm_16_10.png', 'per81_norm_16_11.png', 'per81_norm_16_12.png', 'per81_norm_16_13.png', 'per81_norm_16_14.png', 'per82_norm_1_6.png', 'per82_norm_1_4.png', 'per82_norm_1_7.png', 'per82_norm_1_3.png', 'per82_norm_1_2.png', 'per82_norm_1_5.png', 'per82_norm_1_1.png', 'per82_norm_1_11.png', 'per82_norm_1_12.png', 'per82_norm_1_8.png', 'per82_norm_1_10.png', 'per82_norm_1_9.png', 'per82_norm_1_14.png', 'per82_norm_1_13.png', 'per82_norm_2_1.png', 'per82_norm_2_2.png', 'per82_norm_2_4.png', 'per82_norm_2_3.png', 'per82_norm_2_8.png', 'per82_norm_2_6.png', 'per82_norm_2_7.png', 'per82_norm_2_5.png', 'per82_norm_2_10.png', 'per82_norm_2_11.png', 'per82_norm_2_9.png', 'per82_norm_2_14.png', 'per82_norm_2_12.png', 'per82_norm_2_13.png', 'per82_norm_3_3.png', 'per82_norm_3_1.png', 'per82_norm_3_2.png', 'per82_norm_3_5.png', 'per82_norm_3_4.png', 'per82_norm_3_6.png', 'per82_norm_3_7.png', 'per82_norm_3_8.png', 'per82_norm_3_9.png', 'per82_norm_3_10.png', 'per82_norm_3_13.png', 'per82_norm_3_12.png', 'per82_norm_3_11.png', 'per82_norm_4_1.png', 'per82_norm_3_14.png', 'per82_norm_4_2.png', 'per82_norm_4_3.png', 'per82_norm_4_5.png', 'per82_norm_4_4.png', 'per82_norm_4_6.png', 'per82_norm_4_8.png', 'per82_norm_4_7.png', 'per82_norm_4_10.png', 'per82_norm_4_9.png', 'per82_norm_4_11.png', 'per82_norm_4_12.png', 'per82_norm_4_13.png', 'per82_norm_5_1.png', 'per82_norm_4_14.png', 'per82_norm_5_2.png', 'per82_norm_5_4.png', 'per82_norm_5_3.png', 'per82_norm_5_5.png', 'per82_norm_5_7.png', 'per82_norm_5_6.png', 'per82_norm_5_8.png', 'per82_norm_5_9.png', 'per82_norm_5_10.png', 'per82_norm_5_11.png', 'per82_norm_5_12.png', 'per82_norm_5_13.png', 'per82_norm_5_14.png', 'per82_n ...

# %%
import shutil
#Image_names.remove('.DS_Store')
filebefore = '/content/drive/MyDrive/python_code_major/image_dataset/'
fileafter = '/content/drive/MyDrive/python_code_major/electrode_'
for name in Image_names:
  blah=name.split('_')
  orig=filebefore+name
  print(blah)
  if(int(blah[2])==1):
    newn=fileafter+'1/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==2):
    newn=fileafter+'2/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==3):
    newn=fileafter+'3/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==4):
    newn=fileafter+'4/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==5):
    newn=fileafter+'5/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==6):
    newn=fileafter+'6/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==7):
    newn=fileafter+'7/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==8):
    newn=fileafter+'8/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==9):
    newn=fileafter+'9/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==10):
    newn=fileafter+'10/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==11):
    newn=fileafter+'11/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==12):
    newn=fileafter+'12/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==13):
    newn=fileafter+'13/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==14):
    newn=fileafter+'14/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==15):
    newn=fileafter+'15/'+name
    shutil.copyfile(orig,newn)
  elif(int(blah[2])==16):
    newn=fileafter+'16/'+name
    shutil.copyfile(orig,newn)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['per50', 'norm', '6', '5.png']
# ['per50', 'norm', '6', '6.png']
# ['per50', 'norm', '6', '7.png']
# ['per50', 'norm', '6', '8.png']
# ['per50', 'norm', '6', '9.png']
# ['per50', 'norm', '6', '10.png']
# ['per75', 'norm', '11', '13.png']
# ['per50', 'norm', '6', '11.png']
# ['per50', 'norm', '6', '12.png']
# ['per50', 'norm', '6', '13.png']
# ['per50', 'norm', '6', '14.png']
# ['per50', 'norm', '7', '1.png']
# ['per50', 'norm', '7', '2.png']
# ['per50', 'norm', '7', '3.png']
# ['per50', 'norm', '7', '4.png']
# ['per50', 'norm', '7', '5.png']
# ['per50', 'norm', '7', '6.png']
# ['per50', 'norm', '7', '7.png']
# ['per50', 'norm', '7', '8.png']
# ['per50', 'norm', '7', '9.png']
# ['per50', 'norm', '7', '10.png']
# ['per75', 'norm', '11', '14.png']
# ['per50', 'norm', '7', '11.png']
# ['per50', 'norm', '7', '12.png']
# ['per50', 'norm', '7', '13.png']
# ['per50', 'norm', '7', '14.png']
# ['per50', 'norm', '8', '1.png']
# ['per50', 'norm', '8', '2.png']
# ['per50', 'norm', '8', '3.png']
# ['per50', 'norm', '8', '4.png']
# ['per50', 'norm', '8', '5.png']
# ['per50', 'norm', '8', '6.png']
# ['per50', 'norm', '8', '7.png']
# ['per75', 'norm', '12', '1.png']
# ['per50', 'norm', '8', '8.png']
# ['per50', 'norm', '8', '9.png']
# ['per50', 'norm', '8', '10.png']
# ['per50', 'norm', '8', '11.png']
# ['per50', 'norm', '8', '12.png']
# ['per50', 'norm', '8', '13.png']
# ['per50', 'norm', '8', '14.png']
# ['per50', 'norm', '9', '1.png']
# ['per50', 'norm', '9', '2.png']
# ['per50', 'norm', '9', '3.png']
# ['per50', 'norm', '9', '4.png']
# ['per50', 'norm', '9', '5.png']
# ['per75', 'norm', '12', '2.png']
# ['per50', 'norm', '9', '6.png']
# ['per50', 'norm', '9', '7.png']
# ['per50', 'norm', '9', '8.png']
# ['per50', 'norm', '9', '9.png']
# ['per50', 'norm', '9', '10.png']
# ['per50', 'norm', '9', '11.png']
# ['per50', 'norm', '9', '12.png']
# ['per50', 'norm', '9', '13.png']
# ['per50', 'norm', '9', '14.png']
# ['per50', 'norm', '10', '1.png']
# ['per50', 'norm', '10', '2.png']
# ['per75', 'norm', '12', '3.png']
# ['per50', 'norm', '10', '3.png']
# ['per50', 'norm', '10', '4.png']
# ['per50', 'norm', '10', '5.png']
# ['per50', 'norm', '10', '6.png']
# ['per50', 'norm', '10', '7.png']
# ['per50', 'norm', '10', '8.png']
# ['per50', 'norm', '10', '9.png']
# ['per50', 'norm', '10', '10.png']
# ['per50', 'norm', '10', '11.png']
# ['per75', 'norm', '12', '4.png']
# ['per50', 'norm', '10', '12.png']
# ['per50', 'norm', '10', '13.png']
# ['per50', 'norm', '10', '14.png']
# ['per50', 'norm', '11', '1.png']
# ['per50', 'norm', '11', '2.png']
# ['per50', 'norm', '11', '3.png']
# ['per50', 'norm', '11', '4.png']
# ['per50', 'norm', '11', '5.png']
# ['per75', 'norm', '12', '5.png']
# ['per50', 'norm', '11', '6.png']
# ['per50', 'norm', '11', '7.png']
# ['per50', 'norm', '11', '8.png']
# ['per50', 'norm', '11', '9.png']
# ['per50', 'norm', '11', '10.png']
# ['per50', 'norm', '11', '11.png']
# ['per50', 'norm', '11', '12.png']
# ['per50', 'norm', '11', '13.png']
# ['per50', 'norm', '11', '14.png']
# ['per75', 'norm', '12', '6.png']
# ['per50', 'norm', '12', '1.png']
# ['per50', 'norm', '12', '2.png']
# ['per50', 'norm', '12', '3.png']
# ['per50', 'norm', '12', '4.png']
# ['per50', 'norm', '12', '5.png']
# ['per50', 'norm', '12', '6.png']
# ['per50', 'norm', '12', '7.png']
# ['per50', 'norm', '12', '8.png']
# ['per75', 'norm', '12', '7.png']
# ['per50', 'norm', '12', '9.png']
# ['per50', 'norm', '12', '10.png']
# ['per50', 'norm', '12', '11.png']
# ['per50', 'norm', '12', '12.png']
# ['per50', 'norm', '12', '13.png']
# ['per50', 'norm', '12', '14.png']
# ['per50', 'norm', '13', '1.png']
# ['per75', 'norm', '12', '8.png']
# ['per50', 'norm', '13', '2.png']
# ['per50', 'norm', '13', '3.png']
# ['per50', 'norm', '13', '4.png']
# ['per50', 'norm', '13', '5.png']
# ['per50', 'norm', '13', '6.png']
# ['per50', 'norm', '13', '7.png']
# ['per50', 'norm', '13', '8.png']
# ['per75', 'norm', '12', '9.png']
# ['per50', 'norm', '13', '9.png']
# ['per50', 'norm', '13', '10.png']
# ['per50', 'norm', '13', '11.png']
# ['per50', 'norm', '13', '12.png']
# ['per50', 'norm', '13', '13.png']
# ['per50', 'norm', '13', '14.png']
# ['per50', 'norm', '14', '1.png']
# ['per75', 'norm', '12', '10.png']
# ['per50', 'norm', '14', '2.png']
# ['per50', 'norm', '14', '3.png']
# ['per50', 'norm', '14', '4.png']
# ['per50', 'norm', '14', '5.png']
# ['per50', 'norm', '14', '6.png']
# ['per50', 'norm', '14', '7.png']
# ['per50', 'norm', '14', '8.png']
# ['per75', 'norm', '12', '11.png']
# ['per50', 'norm', '14', '9.png']
# ['per50', 'norm', '14', '10.png']
# ['per50', 'norm', '14', '11.png']
# ['per50', 'norm', '14', '12.png']
# ['per50', 'norm', '14', '13.png']
# ['per50', 'norm', '14', '14.png']
# ['per50', 'norm', '15', '1.png']
# ['per75', 'norm', '12', '12.png']
# ['per50', 'norm', '15', '2.png']
# ['per50', 'norm', '15', '3.png']
# ['per50', 'norm', '15', '4.png']
# ['per50', 'norm', '15', '5.png']
# ['per50', 'norm', '15', '6.png']
# ['per50', 'norm', '15', '7.png']
# ['per75', 'norm', '12', '13.png']
# ['per50', 'norm', '15', '8.png']
# ['per50', 'norm', '15', '9.png']
# ['per50', 'norm', '15', '10.png']
# ['per50', 'norm', '15', '11.png']
# ['per50', 'norm', '15', '12.png']
# ['per50', 'norm', '15', '13.png']
# ['per75', 'norm', '12', '14.png']
# ['per50', 'norm', '15', '14.png']
# ['per50', 'norm', '16', '1.png']
# ['per74', 'norm', '6', '5.png']
# ['per43', 'schiz', '8', '3.png']
# ['per74', 'norm', '6', '6.png']
# ['per43', 'schiz', '8', '4.png']
# ['per43', 'schiz', '8', '5.png']
# ['per74', 'norm', '6', '7.png']
# ['per43', 'schiz', '8', '6.png']
# ['per43', 'schiz', '8', '7.png']
# ['per74', 'norm', '6', '8.png']
# ['per43', 'schiz', '8', '8.png']
# ['per74', 'norm', '6', '9.png']
# ['per43', 'schiz', '8', '9.png']
# ['per43', 'schiz', '8', '10.png']
# ['per74', 'norm', '6', '10.png']
# ['per43', 'schiz', '8', '11.png']
# ['per43', 'schiz', '8', '12.png']
# ['per74', 'norm', '6', '11.png']
# ['per43', 'schiz', '8', '13.png']
# ['per74', 'norm', '6', '12.png']
# ['per43', 'schiz', '8', '14.png']
# ['per43', 'schiz', '9', '1.png']
# ['per74', 'norm', '6', '13.png']
# ['per43', 'schiz', '9', '2.png']
# ['per43', 'schiz', '9', '3.png']
# ['per74', 'norm', '6', '14.png']
# ['per43', 'schiz', '9', '4.png']
# ['per43', 'schiz', '9', '5.png']
# ['per74', 'norm', '7', '1.png']
# ['per43', 'schiz', '9', '6.png']
# ['per74', 'norm', '7', '2.png']
# ['per43', 'schiz', '9', '7.png']
# ['per43', 'schiz', '9', '8.png']
# ['per74', 'norm', '7', '3.png']
# ['per43', 'schiz', '9', '9.png']
# ['per74', 'norm', '7', '4.png']
# ['per43', 'schiz', '9', '10.png']
# ['per43', 'schiz', '9', '11.png']
# ['per74', 'norm', '7', '5.png']
# ['per43', 'schiz', '9', '12.png']
# ['per43', 'schiz', '9', '13.png']
# ['per74', 'norm', '7', '6.png']
# ['per43', 'schiz', '9', '14.png']
# ['per43', 'schiz', '10', '1.png']
# ['per74', 'norm', '7', '7.png']
# ['per43', 'schiz', '10', '2.png']
# ['per74', 'norm', '7', '8.png']
# ['per43', 'schiz', '10', '3.png']
# ['per43', 'schiz', '10', '4.png']
# ['per74', 'norm', '7', '9.png']
# ['per43', 'schiz', '10', '5.png']
# ['per74', 'norm', '7', '10.png']
# ['per43', 'schiz', '10', '6.png']
# ['per43', 'schiz', '10', '7.png']
# ['per74', 'norm', '7', '11.png']
# ['per43', 'schiz', '10', '8.png']
# ['per43', 'schiz', '10', '9.png']
# ['per74', 'norm', '7', '12.png']
# ['per43', 'schiz', '10', '10.png']
# ['per74', 'norm', '7', '13.png']
# ['per43', 'schiz', '10', '11.png']
# ['per43', 'schiz', '10', '12.png']
# ['per74', 'norm', '7', '14.png']
# ['per43', 'schiz', '10', '13.png']
# ['per43', 'schiz', '10', '14.png']
# ['per74', 'norm', '8', '1.png']
# ['per43', 'schiz', '11', '1.png']
# ['per74', 'norm', '8', '2.png']
# ['per43', 'schiz', '11', '2.png']
# ['per43', 'schiz', '11', '3.png']
# ['per74', 'norm', '8', '3.png']
# ['per43', 'schiz', '11', '4.png']
# ['per43', 'schiz', '11', '5.png']
# ['per74', 'norm', '8', '4.png']
# ['per43', 'schiz', '11', '6.png']
# ['per74', 'norm', '8', '5.png']
# ['per43', 'schiz', '11', '7.png']
# ['per43', 'schiz', '11', '8.png']
# ['per74', 'norm', '8', '6.png']
# ['per43', 'schiz', '11', '9.png']
# ['per74', 'norm', '8', '7.png']
# ['per43', 'schiz', '11', '10.png']
# ['per43', 'schiz', '11', '11.png']
# ['per74', 'norm', '8', '8.png']
# ['per43', 'schiz', '11', '12.png']
# ['per43', 'schiz', '11', '13.png']
# ['per74', 'norm', '8', '9.png']
# ['per43', 'schiz', '11', '14.png']
# ['per74', 'norm', '8', '10.png']
# ['per43', 'schiz', '12', '1.png']
# ['per43', 'schiz', '12', '2.png']
# ['per74', 'norm', '8', '11.png']
# ['per43', 'schiz', '12', '3.png']
# ['per43', 'schiz', '12', '4.png']
# ['per74', 'norm', '8', '12.png']
# ['per43', 'schiz', '12', '5.png']
# ['per74', 'norm', '8', '13.png']
# ['per43', 'schiz', '12', '6.png']
# ['per43', 'schiz', '12', '7.png']
# ['per74', 'norm', '8', '14.png']
# ['per43', 'schiz', '12', '8.png']
# ['per43', 'schiz', '12', '9.png']
# ['per74', 'norm', '9', '1.png']
# ['per43', 'schiz', '12', '10.png']
# ['per74', 'norm', '9', '2.png']
# ['per43', 'schiz', '12', '11.png']
# ['per43', 'schiz', '12', '12.png']
# ['per74', 'norm', '9', '3.png']
# ['per43', 'schiz', '12', '13.png']
# ['per74', 'norm', '9', '4.png']
# ['per43', 'schiz', '12', '14.png']
# ['per43', 'schiz', '13', '1.png']
# ['per74', 'norm', '9', '5.png']
# ['per43', 'schiz', '13', '2.png']
# ['per43', 'schiz', '13', '3.png']
# ['per74', 'norm', '9', '6.png']
# ['per43', 'schiz', '13', '4.png']
# ['per74', 'norm', '9', '7.png']
# ['per43', 'schiz', '13', '5.png']
# ['per43', 'schiz', '13', '6.png']
# ['per74', 'norm', '9', '8.png']
# ['per43', 'schiz', '13', '7.png']
# ['per74', 'norm', '9', '9.png']
# ['per43', 'schiz', '13', '8.png']
# ['per43', 'schiz', '13', '9.png']
# ['per74', 'norm', '9', '10.png']
# ['per43', 'schiz', '13', '10.png']
# ['per74', 'norm', '9', '11.png']
# ['per43', 'schiz', '13', '11.png']
# ['per43', 'schiz', '13', '12.png']
# ['per74', 'norm', '9', '12.png']
# ['per43', 'schiz', '13', '13.png']
# ['per43', 'schiz', '13', '14.png']
# ['per74', 'norm', '9', '13.png']
# ['per43', 'schiz', '14', '1.png']
# ['per74', 'norm', '9', '14.png']
# ['per43', 'schiz', '14', '2.png']
# ['per43', 'schiz', '14', '3.png']
# ['per74', 'norm', '10', '1.png']
# ['per43', 'schiz', '14', '4.png']
# ['per43', 'schiz', '14', '5.png']
# ['per74', 'norm', '10', '2.png']
# ['per43', 'schiz', '14', '6.png']
# ['per74', 'norm', '10', '3.png']
# ['per43', 'schiz', '14', '7.png']
# ['per43', 'schiz', '14', '8.png']
# ['per74', 'norm', '10', '4.png']
# ['per43', 'schiz', '14', '9.png']
# ['per74', 'norm', '10', '5.png']
# ['per43', 'schiz', '14', '10.png']
# ['per43', 'schiz', '14', '11.png']
# ['per74', 'norm', '10', '6.png']
# ['per43', 'schiz', '14', '12.png']
# ['per74', 'norm', '10', '7.png']
# ['per43', 'schiz', '14', '13.png']
# ['per43', 'schiz', '14', '14.png']
# ['per74', 'norm', '10', '8.png']
# ['per43', 'schiz', '15', '1.png']
# ['per43', 'schiz', '15', '2.png']
# ['per74', 'norm', '10', '9.png']
# ['per43', 'schiz', '15', '3.png']
# ['per74', 'norm', '10', '10.png']
# ['per43', 'schiz', '15', '4.png']
# ['per43', 'schiz', '15', '5.png']
# ['per74', 'norm', '10', '11.png']
# ['per43', 'schiz', '15', '6.png']
# ['per74', 'norm', '10', '12.png']
# ['per43', 'schiz', '15', '7.png']
# ['per43', 'schiz', '15', '8.png']
# ['per74', 'norm', '10', '13.png']
# ['per43', 'schiz', '15', '9.png']
# ['per74', 'norm', '10', '14.png']
# ['per43', 'schiz', '15', '10.png']
# ['per43', 'schiz', '15', '11.png']
# ['per74', 'norm', '11', '1.png']
# ['per43', 'schiz', '15', '12.png']
# ['per74', 'norm', '11', '2.png']
# ['per43', 'schiz', '15', '13.png']
# ['per43', 'schiz', '15', '14.png']
# ['per74', 'norm', '11', '3.png']
# ['per43', 'schiz', '16', '1.png']
# ['per74', 'norm', '11', '4.png']
# ['per43', 'schiz', '16', '2.png']
# ['per74', 'norm', '11', '5.png']
# ['per43', 'schiz', '16', '3.png']
# ['per43', 'schiz', '16', '4.png']
# ['per74', 'norm', '11', '6.png']
# ['per43', 'schiz', '16', '5.png']
# ['per74', 'norm', '11', '7.png']
# ['per43', 'schiz', '16', '6.png']
# ['per43', 'schiz', '16', '7.png']
# ['per74', 'norm', '11', '8.png']
# ['per43', 'schiz', '16', '8.png']
# ['per74', 'norm', '11', '9.png']
# ['per43', 'schiz', '16', '9.png']
# ['per43', 'schiz', '16', '10.png']
# ['per74', 'norm', '11', '10.png']
# ['per43', 'schiz', '16', '11.png']
# ['per74', 'norm', '11', '11.png']
# ['per43', 'schiz', '16', '12.png']
# ['per43', 'schiz', '16', '13.png']
# ['per74', 'norm', '11', '12.png']
# ['per43', 'schiz', '16', '14.png']
# ['per74', 'norm', '11', '13.png']
# ['per74', 'norm', '11', '14.png']
# ['per74', 'norm', '12', '1.png']
# ['per74', 'norm', '12', '2.png']
# ['per74', 'norm', '12', '3.png']
# ['per74', 'norm', '12', '4.png']
# ['per74', 'norm', '12', '5.png']
# ['per74', 'norm', '12', '6.png']
# ['per74', 'norm', '12', '7.png']
# ['per44', 'schiz', '1', '1.png']
# ['per44', 'schiz', '1', '4.png']
# ['per44', 'schiz', '1', '6.png']
# ['per44', 'schiz', '1', '7.png']
# ['per44', 'schiz', '1', '3.png']
# ['per44', 'schiz', '1', '5.png']
# ['per44', 'schiz', '1', '8.png']
# ['per44', 'schiz', '1', '9.png']
# ['per44', 'schiz', '1', '2.png']
# ['per44', 'schiz', '1', '11.png']
# ['per74', 'norm', '12', '8.png']
# ['per44', 'schiz', '1', '10.png']
# ['per44', 'schiz', '1', '12.png']
# ['per44', 'schiz', '1', '13.png']
# ['per44', 'schiz', '1', '14.png']
# ['per44', 'schiz', '2', '4.png']
# ['per44', 'schiz', '2', '2.png']
# ['per44', 'schiz', '2', '3.png']
# ['per44', 'schiz', '2', '1.png']
# ['per44', 'schiz', '2', '6.png']
# ['per44', 'schiz', '2', '8.png']
# ['per44', 'schiz', '2', '5.png']
# ['per44', 'schiz', '2', '7.png']
# ['per44', 'schiz', '2', '10.png']
# ['per44', 'schiz', '2', '9.png']
# ['per44', 'schiz', '2', '11.png']
# ['per44', 'schiz', '2', '12.png']
# ['per44', 'schiz', '2', '13.png']
# ['per44', 'schiz', '2', '14.png']
# ['per44', 'schiz', '3', '2.png']
# ['per44', 'schiz', '3', '1.png']
# ['per44', 'schiz', '3', '3.png']
# ['per44', 'schiz', '3', '4.png']
# ['per44', 'schiz', '3', '7.png']
# ['per44', 'schiz', '3', '6.png']
# ['per44', 'schiz', '3', '5.png']
# ['per44', 'schiz', '3', '8.png']
# ['per44', 'schiz', '3', '9.png']
# ['per44', 'schiz', '3', '10.png']
# ['per44', 'schiz', '3', '11.png']
# ['per44', 'schiz', '3', '12.png']
# ['per44', 'schiz', '3', '14.png']
# ['per44', 'schiz', '3', '13.png']
# ['per44', 'schiz', '4', '1.png']
# ['per44', 'schiz', '4', '2.png']
# ['per44', 'schiz', '4', '3.png']
# ['per74', 'norm', '12', '9.png']
# ['per44', 'schiz', '4', '4.png']
# ['per44', 'schiz', '4', '5.png']
# ['per44', 'schiz', '4', '6.png']
# ['per44', 'schiz', '4', '7.png']
# ['per44', 'schiz', '4', '8.png']
# ['per44', 'schiz', '4', '9.png']
# ['per44', 'schiz', '4', '10.png']
# ['per44', 'schiz', '4', '11.png']
# ['per44', 'schiz', '4', '12.png']
# ['per44', 'schiz', '4', '13.png']
# ['per44', 'schiz', '4', '14.png']
# ['per44', 'schiz', '5', '1.png']
# ['per44', 'schiz', '5', '2.png']
# ['per44', 'schiz', '5', '3.png']
# ['per44', 'schiz', '5', '4.png']
# ['per44', 'schiz', '5', '5.png']
# ['per74', 'norm', '12', '10.png']
# ['per44', 'schiz', '5', '6.png']
# ['per44', 'schiz', '5', '7.png']
# ['per44', 'schiz', '5', '8.png']
# ['per44', 'schiz', '5', '9.png']
# ['per44', 'schiz', '5', '10.png']
# ['per44', 'schiz', '5', '11.png']
# ['per44', 'schiz', '5', '12.png']
# ['per44', 'schiz', '5', '13.png']
# ['per44', 'schiz', '5', '14.png']
# ['per44', 'schiz', '6', '1.png']
# ['per44', 'schiz', '6', '2.png']
# ['per44', 'schiz', '6', '3.png']
# ['per44', 'schiz', '6', '4.png']
# ['per44', 'schiz', '6', '5.png']
# ['per74', 'norm', '12', '11.png']
# ['per44', 'schiz', '6', '6.png']
# ['per44', 'schiz', '6', '7.png']
# ['per44', 'schiz', '6', '8.png']
# ['per44', 'schiz', '6', '9.png']
# ['per44', 'schiz', '6', '10.png']
# ['per44', 'schiz', '6', '11.png']
# ['per44', 'schiz', '6', '12.png']
# ['per44', 'schiz', '6', '13.png']
# ['per44', 'schiz', '6', '14.png']
# ['per44', 'schiz', '7', '1.png']
# ['per44', 'schiz', '7', '2.png']
# ['per74', 'norm', '12', '12.png']
# ['per44', 'schiz', '7', '3.png']
# ['per44', 'schiz', '7', '4.png']
# ['per44', 'schiz', '7', '5.png']
# ['per44', 'schiz', '7', '6.png']
# ['per44', 'schiz', '7', '7.png']
# ['per44', 'schiz', '7', '8.png']
# ['per44', 'schiz', '7', '9.png']
# ['per44', 'schiz', '7', '10.png']
# ['per44', 'schiz', '7', '11.png']
# ['per44', 'schiz', '7', '12.png']
# ['per44', 'schiz', '7', '13.png']
# ['per44', 'schiz', '7', '14.png']
# ['per74', 'norm', '12', '13.png']
# ['per44', 'schiz', '8', '1.png']
# ['per44', 'schiz', '8', '2.png']
# ['per44', 'schiz', '8', '3.png']
# ['per44', 'schiz', '8', '4.png']
# ['per44', 'schiz', '8', '5.png']
# ['per44', 'schiz', '8', '6.png']
# ['per44', 'schiz', '8', '7.png']
# ['per44', 'schiz', '8', '8.png']
# ['per44', 'schiz', '8', '9.png']
# ['per74', 'norm', '12', '14.png']
# ['per44', 'schiz', '8', '10.png']
# ['per44', 'schiz', '8', '11.png']
# ['per44', 'schiz', '8', '12.png']
# ['per44', 'schiz', '8', '13.png']
# ['per44', 'schiz', '8', '14.png']
# ['per44', 'schiz', '9', '1.png']
# ['per44', 'schiz', '9', '2.png']
# ['per44', 'schiz', '9', '3.png']
# ['per74', 'norm', '13', '1.png']
# ['per44', 'schiz', '9', '4.png']
# ['per44', 'schiz', '9', '5.png']
# ['per44', 'schiz', '9', '6.png']
# ['per44', 'schiz', '9', '7.png']
# ['per44', 'schiz', '9', '8.png']
# ['per44', 'schiz', '9', '9.png']
# ['per44', 'schiz', '9', '10.png']
# ['per44', 'schiz', '9', '11.png']
# ['per44', 'schiz', '9', '12.png']
# ['per74', 'norm', '13', '2.png']
# ['per44', 'schiz', '9', '13.png']
# ['per44', 'schiz', '9', '14.png']
# ['per44', 'schiz', '10', '1.png']
# ['per44', 'schiz', '10', '2.png']
# ['per44', 'schiz', '10', '3.png']
# ['per44', 'schiz', '10', '4.png']
# ['per44', 'schiz', '10', '5.png']
# ['per74', 'norm', '13', '3.png']
# ['per44', 'schiz', '10', '6.png']
# ['per44', 'schiz', '10', '7.png']
# ['per44', 'schiz', '10', '8.png']
# ['per44', 'schiz', '10', '9.png']
# ['per44', 'schiz', '10', '10.png']
# ['per44', 'schiz', '10', '11.png']
# ['per44', 'schiz', '10', '12.png']
# ['per74', 'norm', '13', '4.png']
# ['per44', 'schiz', '10', '13.png']
# ['per44', 'schiz', '10', '14.png']
# ['per44', 'schiz', '11', '1.png']
# ['per44', 'schiz', '11', '2.png']
# ['per44', 'schiz', '11', '3.png']
# ['per44', 'schiz', '11', '4.png']
# ['per44', 'schiz', '11', '5.png']
# ['per74', 'norm', '13', '5.png']
# ['per44', 'schiz', '11', '6.png']
# ['per44', 'schiz', '11', '7.png']
# ['per44', 'schiz', '11', '8.png']
# ['per44', 'schiz', '11', '9.png']
# ['per44', 'schiz', '11', '10.png']
# ['per44', 'schiz', '11', '11.png']
# ['per74', 'norm', '13', '6.png']
# ['per44', 'schiz', '11', '12.png']
# ['per44', 'schiz', '11', '13.png']
# ['per44', 'schiz', '11', '14.png']
# ['per44', 'schiz', '12', '1.png']
# ['per44', 'schiz', '12', '2.png']
# ['per44', 'schiz', '12', '3.png']
# ['per44', 'schiz', '12', '4.png']
# ['per74', 'norm', '13', '7.png']
# ['per44', 'schiz', '12', '5.png']
# ['per44', 'schiz', '12', '6.png']
# ['per44', 'schiz', '12', '7.png']
# ['per44', 'schiz', '12', '8.png']
# ['per44', 'schiz', '12', '9.png']
# ['per44', 'schiz', '12', '10.png']
# ['per44', 'schiz', '12', '11.png']
# ['per74', 'norm', '13', '8.png']
# ['per44', 'schiz', '12', '12.png']
# ['per44', 'schiz', '12', '13.png']
# ['per44', 'schiz', '12', '14.png']
# ['per44', 'schiz', '13', '1.png']
# ['per44', 'schiz', '13', '2.png']
# ['per74', 'norm', '13', '9.png']
# ['per44', 'schiz', '13', '3.png']
# ['per44', 'schiz', '13', '4.png']
# ['per44', 'schiz', '13', '5.png']
# ['per44', 'schiz', '13', '6.png']
# ['per44', 'schiz', '13', '7.png']
# ['per44', 'schiz', '13', '8.png']
# ['per74', 'norm', '13', '10.png']
# ['per44', 'schiz', '13', '9.png']
# ['per44', 'schiz', '13', '10.png']
# ['per44', 'schiz', '13', '11.png']
# ['per44', 'schiz', '13', '12.png']
# ['per44', 'schiz', '13', '13.png']
# ['per74', 'norm', '13', '11.png']
# ['per44', 'schiz', '13', '14.png']
# ['per44', 'schiz', '14', '1.png']
# ['per44', 'schiz', '14', '2.png']
# ['per44', 'schiz', '14', '3.png']
# ['per44', 'schiz', '14', '4.png']
# ['per44', 'schiz', '14', '5 (1).png']
# ['per44', 'schiz', '14', '5.png']
# ['per74', 'norm', '13', '12.png']
# ['per44', 'schiz', '14', '6.png']
# ['per44', 'schiz', '14', '7.png']
# ['per44', 'schiz', '14', '8.png']
# ['per44', 'schiz', '14', '9.png']
# ['per44', 'schiz', '14', '10.png']
# ['per74', 'norm', '13', '13.png']
# ['per44', 'schiz', '14', '11.png']
# ['per44', 'schiz', '14', '12.png']
# ['per44', 'schiz', '14', '13.png']
# ['per44', 'schiz', '14', '14.png']
# ['per44', 'schiz', '15', '1.png']
# ['per74', 'norm', '13', '14.png']
# ['per44', 'schiz', '15', '2.png']
# ['per44', 'schiz', '15', '3.png']
# ['per44', 'schiz', '15', '4.png']
# ['per44', 'schiz', '15', '5.png']
# ['per44', 'schiz', '15', '6.png']
# ['per74', 'norm', '14', '1.png']
# ['per44', 'schiz', '15', '7.png']
# ['per44', 'schiz', '15', '8.png']
# ['per44', 'schiz', '15', '9.png']
# ['per44', 'schiz', '15', '10.png']
# ['per44', 'schiz', '15', '11.png']
# ['per74', 'norm', '14', '2.png']
# ['per44', 'schiz', '15', '12.png']
# ['per44', 'schiz', '15', '13.png']
# ['per44', 'schiz', '15', '14.png']
# ['per44', 'schiz', '16', '1.png']
# ['per44', 'schiz', '16', '2.png']
# ['per74', 'norm', '14', '3.png']
# ['per44', 'schiz', '16', '3.png']
# ['per44', 'schiz', '16', '4.png']
# ['per44', 'schiz', '16', '5.png']
# ['per44', 'schiz', '16', '6.png']
# ['per74', 'norm', '14', '4.png']
# ['per44', 'schiz', '16', '7.png']
# ['per44', 'schiz', '16', '8.png']
# ['per44', 'schiz', '16', '9.png']
# ['per44', 'schiz', '16', '10.png']
# ['per44', 'schiz', '16', '11.png']
# ['per74', 'norm', '14', '5.png']
# ['per44', 'schiz', '16', '12.png']
# ['per44', 'schiz', '16', '13.png']
# ['per44', 'schiz', '16', '14.png']
# ['per74', 'norm', '14', '6.png']
# ['per74', 'norm', '14', '7.png']
# ['per74', 'norm', '14', '8.png']
# ['per74', 'norm', '14', '9.png']
# ['per74', 'norm', '14', '10.png']
# ['per74', 'norm', '14', '11.png']
# ['per45', 'schiz', '1', '4.png']
# ['per45', 'schiz', '1', '5.png']
# ['per45', 'schiz', '1', '2.png']
# ['per45', 'schiz', '1', '3.png']
# ['per45', 'schiz', '1', '1.png']
# ['per45', 'schiz', '1', '7.png']
# ['per45', 'schiz', '1', '10.png']
# ['per45', 'schiz', '1', '9.png']
# ['per45', 'schiz', '1', '11.png']
# ['per45', 'schiz', '1', '6.png']
# ['per45', 'schiz', '1', '8.png']
# ['per45', 'schiz', '1', '12.png']
# ['per45', 'schiz', '2', '2.png']
# ['per45', 'schiz', '2', '1.png']
# ['per45', 'schiz', '1', '13.png']
# ['per45', 'schiz', '1', '14.png']
# ['per45', 'schiz', '2', '6.png']
# ['per45', 'schiz', '2', '4.png']
# ['per45', 'schiz', '2', '3.png']
# ['per45', 'schiz', '2', '5.png']
# ['per45', 'schiz', '2', '8.png']
# ['per45', 'schiz', '2', '9.png']
# ['per45', 'schiz', '2', '7.png']
# ['per45', 'schiz', '2', '10.png']
# ['per45', 'schiz', '2', '12.png']
# ['per45', 'schiz', '2', '11.png']
# ['per45', 'schiz', '3', '1.png']
# ['per45', 'schiz', '2', '14.png']
# ['per45', 'schiz', '2', '13.png']
# ['per45', 'schiz', '3', '3.png']
# ['per74', 'norm', '14', '12.png']
# ['per45', 'schiz', '3', '2.png']
# ['per45', 'schiz', '3', '4.png']
# ['per45', 'schiz', '3', '5.png']
# ['per45', 'schiz', '3', '6.png']
# ['per45', 'schiz', '3', '7.png']
# ['per45', 'schiz', '3', '9.png']
# ['per45', 'schiz', '3', '8.png']
# ['per45', 'schiz', '3', '10.png']
# ['per45', 'schiz', '3', '11.png']
# ['per45', 'schiz', '3', '12.png']
# ['per45', 'schiz', '3', '13.png']
# ['per45', 'schiz', '3', '14.png']
# ['per45', 'schiz', '4', '1.png']
# ['per45', 'schiz', '4', '2.png']
# ['per45', 'schiz', '4', '3.png']
# ['per45', 'schiz', '4', '4.png']
# ['per45', 'schiz', '4', '5.png']
# ['per45', 'schiz', '4', '6.png']
# ['per45', 'schiz', '4', '7.png']
# ['per45', 'schiz', '4', '9.png']
# ['per45', 'schiz', '4', '8.png']
# ['per45', 'schiz', '4', '10.png']
# ['per45', 'schiz', '4', '11.png']
# ['per45', 'schiz', '4', '12.png']
# ['per45', 'schiz', '4', '13.png']
# ['per74', 'norm', '14', '13.png']
# ['per45', 'schiz', '4', '14.png']
# ['per45', 'schiz', '5', '1.png']
# ['per45', 'schiz', '5', '2.png']
# ['per45', 'schiz', '5', '3.png']
# ['per45', 'schiz', '5', '4.png']
# ['per45', 'schiz', '5', '5.png']
# ['per45', 'schiz', '5', '6.png']
# ['per45', 'schiz', '5', '7.png']
# ['per45', 'schiz', '5', '8.png']
# ['per45', 'schiz', '5', '9.png']
# ['per45', 'schiz', '5', '10.png']
# ['per45', 'schiz', '5', '11.png']
# ['per45', 'schiz', '5', '12.png']
# ['per45', 'schiz', '5', '13.png']
# ['per45', 'schiz', '5', '14.png']
# ['per74', 'norm', '14', '14.png']
# ['per45', 'schiz', '6', '1.png']
# ['per45', 'schiz', '6', '2.png']
# ['per45', 'schiz', '6', '3.png']
# ['per45', 'schiz', '6', '4.png']
# ['per45', 'schiz', '6', '5.png']
# ['per45', 'schiz', '6', '6.png']
# ['per45', 'schiz', '6', '7.png']
# ['per45', 'schiz', '6', '8.png']
# ['per45', 'schiz', '6', '9.png']
# ['per45', 'schiz', '6', '10.png']
# ['per45', 'schiz', '6', '11.png']
# ['per45', 'schiz', '6', '12.png']
# ['per45', 'schiz', '6', '13.png']
# ['per74', 'norm', '15', '1.png']
# ['per45', 'schiz', '6', '14.png']
# ['per45', 'schiz', '7', '1.png']
# ['per45', 'schiz', '7', '2.png']
# ['per45', 'schiz', '7', '3.png']
# ['per45', 'schiz', '7', '4.png']
# ['per45', 'schiz', '7', '5.png']
# ['per45', 'schiz', '7', '6.png']
# ['per45', 'schiz', '7', '7.png']
# ['per45', 'schiz', '7', '8.png']
# ['per45', 'schiz', '7', '9.png']
# ['per45', 'schiz', '7', '10.png']
# ['per74', 'norm', '15', '2.png']
# ['per45', 'schiz', '7', '11.png']
# ['per45', 'schiz', '7', '12.png']
# ['per45', 'schiz', '7', '13.png']
# ['per45', 'schiz', '7', '14.png']
# ['per45', 'schiz', '8', '1.png']
# ['per45', 'schiz', '8', '2.png']
# ['per45', 'schiz', '8', '3.png']
# ['per45', 'schiz', '8', '4.png']
# ['per45', 'schiz', '8', '5.png']
# ['per45', 'schiz', '8', '6.png']
# ['per74', 'norm', '15', '3.png']
# ['per45', 'schiz', '8', '7.png']
# ['per45', 'schiz', '8', '8.png']
# ['per45', 'schiz', '8', '9.png']
# ['per45', 'schiz', '8', '10.png']
# ['per45', 'schiz', '8', '11.png']
# ['per45', 'schiz', '8', '12.png']
# ['per45', 'schiz', '8', '13.png']
# ['per45', 'schiz', '8', '14.png']
# ['per45', 'schiz', '9', '1.png']
# ['per74', 'norm', '15', '4.png']
# ['per45', 'schiz', '9', '2.png']
# ['per45', 'schiz', '9', '3.png']
# ['per45', 'schiz', '9', '4.png']
# ['per45', 'schiz', '9', '5.png']
# ['per45', 'schiz', '9', '6.png']
# ['per45', 'schiz', '9', '7.png']
# ['per45', 'schiz', '9', '8.png']
# ['per45', 'schiz', '9', '9.png']
# ['per74', 'norm', '15', '5.png']
# ['per45', 'schiz', '9', '10.png']
# ['per45', 'schiz', '9', '11.png']
# ['per45', 'schiz', '9', '12.png']
# ['per45', 'schiz', '9', '13.png']
# ['per45', 'schiz', '9', '14.png']
# ['per45', 'schiz', '10', '1.png']
# ['per45', 'schiz', '10', '2.png']
# ['per45', 'schiz', '10', '3.png']
# ['per74', 'norm', '15', '6.png']
# ['per45', 'schiz', '10', '4.png']
# ['per45', 'schiz', '10', '5.png']
# ['per45', 'schiz', '10', '6.png']
# ['per45', 'schiz', '10', '7.png']
# ['per45', 'schiz', '10', '8.png']
# ['per45', 'schiz', '10', '9.png']
# ['per45', 'schiz', '10', '10.png']
# ['per45', 'schiz', '10', '11.png']
# ['per74', 'norm', '15', '7.png']
# ['per45', 'schiz', '10', '12.png']
# ['per45', 'schiz', '10', '13.png']
# ['per45', 'schiz', '10', '14.png']
# ['per45', 'schiz', '11', '1.png']
# ['per45', 'schiz', '11', '2.png']
# ['per45', 'schiz', '11', '3.png']
# ['per45', 'schiz', '11', '4.png']
# ['per74', 'norm', '15', '8.png']
# ['per45', 'schiz', '11', '5.png']
# ['per45', 'schiz', '11', '6.png']
# ['per45', 'schiz', '11', '7.png']
# ['per45', 'schiz', '11', '8.png']
# ['per45', 'schiz', '11', '9.png']
# ['per45', 'schiz', '11', '10.png']
# ['per45', 'schiz', '11', '11.png']
# ['per74', 'norm', '15', '9.png']
# ['per45', 'schiz', '11', '12.png']
# ['per45', 'schiz', '11', '13.png']
# ['per45', 'schiz', '11', '14.png']
# ['per45', 'schiz', '12', '1.png']
# ['per45', 'schiz', '12', '2.png']
# ['per45', 'schiz', '12', '3.png']
# ['per45', 'schiz', '12', '4.png']
# ['per74', 'norm', '15', '10.png']
# ['per45', 'schiz', '12', '5.png']
# ['per45', 'schiz', '12', '6.png']
# ['per45', 'schiz', '12', '7.png']
# ['per45', 'schiz', '12', '8.png']
# ['per45', 'schiz', '12', '9.png']
# ['per45', 'schiz', '12', '10.png']
# ['per74', 'norm', '15', '11.png']
# ['per45', 'schiz', '12', '11.png']
# ['per45', 'schiz', '12', '12.png']
# ['per45', 'schiz', '12', '13.png']
# ['per45', 'schiz', '12', '14.png']
# ['per45', 'schiz', '13', '1.png']
# ['per45', 'schiz', '13', '2.png']
# ['per74', 'norm', '15', '12.png']
# ['per45', 'schiz', '13', '3.png']
# ['per45', 'schiz', '13', '4.png']
# ['per45', 'schiz', '13', '5.png']
# ['per45', 'schiz', '13', '6.png']
# ['per45', 'schiz', '13', '7.png']
# ['per74', 'norm', '15', '13.png']
# ['per45', 'schiz', '13', '8.png']
# ['per45', 'schiz', '13', '9.png']
# ['per45', 'schiz', '13', '10.png']
# ['per45', 'schiz', '13', '11.png']
# ['per45', 'schiz', '13', '12.png']
# ['per45', 'schiz', '13', '13.png']
# ['per74', 'norm', '15', '14.png']
# ['per45', 'schiz', '13', '14.png']
# ['per45', 'schiz', '14', '1.png']
# ['per45', 'schiz', '14', '2.png']
# ['per45', 'schiz', '14', '3.png']
# ['per45', 'schiz', '14', '4.png']
# ['per74', 'norm', '16', '1.png']
# ['per45', 'schiz', '14', '5.png']
# ['per45', 'schiz', '14', '6.png']
# ['per45', 'schiz', '14', '7.png']
# ['per45', 'schiz', '14', '8.png']
# ['per45', 'schiz', '14', '9.png']
# ['per45', 'schiz', '14', '10.png']
# ['per74', 'norm', '16', '2.png']
# ['per45', 'schiz', '14', '11.png']
# ['per45', 'schiz', '14', '12.png']
# ['per45', 'schiz', '14', '13.png']
# ['per45', 'schiz', '14', '14.png']
# ['per45', 'schiz', '15', '1.png']
# ['per74', 'norm', '16', '3.png']
# ['per45', 'schiz', '15', '2.png']
# ['per45', 'schiz', '15', '3.png']
# ['per45', 'schiz', '15', '4.png']
# ['per45', 'schiz', '15', '5.png']
# ['per45', 'schiz', '15', '6.png']
# ['per74', 'norm', '16', '4.png']
# ['per45', 'schiz', '15', '7.png']
# ['per45', 'schiz', '15', '8.png']
# ['per45', 'schiz', '15', '9.png']
# ['per45', 'schiz', '15', '10.png']
# ['per45', 'schiz', '15', '11.png']
# ['per74', 'norm', '16', '5.png']
# ['per45', 'schiz', '15', '12.png']
# ['per45', 'schiz', '15', '13.png']
# ['per45', 'schiz', '15', '14.png']
# ['per45', 'schiz', '16', '1.png']
# ['per45', 'schiz', '16', '2.png']
# ['per74', 'norm', '16', '6.png']
# ['per45', 'schiz', '16', '3.png']
# ['per45', 'schiz', '16', '4.png']
# ['per45', 'schiz', '16', '5.png']
# ['per45', 'schiz', '16', '6.png']
# ['per45', 'schiz', '16', '7.png']
# ['per74', 'norm', '16', '7.png']
# ['per45', 'schiz', '16', '8.png']
# ['per45', 'schiz', '16', '9.png']
# ['per45', 'schiz', '16', '10.png']
# ['per45', 'schiz', '16', '11.png']
# ['per74', 'norm', '16', '8.png']
# ['per45', 'schiz', '16', '12.png']
# ['per45', 'schiz', '16', '13.png']
# ['per45', 'schiz', '16', '14.png']
# ['per74', 'norm', '16', '9.png']
# ['per74', 'norm', '16', '10.png']
# ['per74', 'norm', '16', '11.png']
# ['per74', 'norm', '16', '12.png']
# ['per74', 'norm', '16', '13.png']
# ['per74', 'norm', '16', '14.png']
# ['per75', 'norm', '1', '1.png']
# ['per75', 'norm', '1', '2.png']
# ['per75', 'norm', '1', '3.png']
# ['per75', 'norm', '1', '4.png']
# ['per75', 'norm', '1', '5.png']
# ['per75', 'norm', '1', '6.png']
# ['per75', 'norm', '1', '7.png']
# ['per75', 'norm', '1', '8.png']
# ['per75', 'norm', '1', '9.png']
# ['per75', 'norm', '1', '10.png']
# ['per75', 'norm', '1', '11.png']
# ['per75', 'norm', '1', '12.png']
# ['per75', 'norm', '1', '13.png']
# ['per75', 'norm', '1', '14.png']
# ['per75', 'norm', '2', '1.png']
# ['per75', 'norm', '2', '2.png']
# ['per75', 'norm', '2', '3.png']
# ['per75', 'norm', '2', '4.png']
# ['per75', 'norm', '2', '5.png']
# ['per75', 'norm', '2', '6.png']
# ['per75', 'norm', '2', '7.png']
# ['per75', 'norm', '2', '8.png']
# ['per75', 'norm', '2', '9.png']
# ['per75', 'norm', '2', '10.png']
# ['per75', 'norm', '2', '11.png']
# ['per75', 'norm', '2', '12.png']
# ['per75', 'norm', '2', '13.png']
# ['per75', 'norm', '2', '14.png']
# ['per75', 'norm', '3', '1.png']
# ['per75', 'norm', '3', '2.png']
# ['per75', 'norm', '3', '3.png']
# ['per75', 'norm', '3', '4.png']
# ['per75', 'norm', '3', '5.png']
# ['per75', 'norm', '3', '6.png']
# ['per75', 'norm', '3', '7.png']
# ['per75', 'norm', '3', '8.png']
# ['per75', 'norm', '3', '9.png']
# ['per75', 'norm', '3', '10.png']
# ['per75', 'norm', '3', '11.png']
# ['per75', 'norm', '3', '12.png']
# ['per75', 'norm', '3', '13.png']
# ['per75', 'norm', '3', '14.png']
# ['per75', 'norm', '4', '1.png']
# ['per75', 'norm', '4', '2.png']
# ['per75', 'norm', '4', '3.png']
# ['per75', 'norm', '4', '4.png']
# ['per75', 'norm', '4', '5.png']
# ['per75', 'norm', '4', '6.png']
# ['per75', 'norm', '4', '7.png']
# ['per75', 'norm', '4', '8.png']
# ['per75', 'norm', '4', '9.png']
# ['per75', 'norm', '4', '10.png']
# ['per75', 'norm', '4', '11.png']
# ['per46', 'norm', '1', '1.png']
# ['per46', 'norm', '1', '2.png']
# ['per46', 'norm', '1', '3.png']
# ['per46', 'norm', '1', '4.png']
# ['per46', 'norm', '1', '10.png']
# ['per46', 'norm', '1', '5.png']
# ['per46', 'norm', '1', '11.png']
# ['per46', 'norm', '1', '7.png']
# ['per46', 'norm', '1', '8.png']
# ['per46', 'norm', '1', '12.png']
# ['per46', 'norm', '1', '6.png']
# ['per46', 'norm', '1', '9.png']
# ['per46', 'norm', '2', '2.png']
# ['per46', 'norm', '1', '13.png']
# ['per46', 'norm', '2', '1.png']
# ['per46', 'norm', '1', '14.png']
# ['per46', 'norm', '2', '4.png']
# ['per46', 'norm', '2', '3.png']
# ['per46', 'norm', '2', '5.png']
# ['per46', 'norm', '2', '6.png']
# ['per46', 'norm', '2', '9.png']
# ['per46', 'norm', '2', '8.png']
# ['per46', 'norm', '2', '7.png']
# ['per46', 'norm', '2', '11.png']
# ['per46', 'norm', '2', '10.png']
# ['per46', 'norm', '2', '12.png']
# ['per46', 'norm', '2', '14.png']
# ['per46', 'norm', '3', '1.png']
# ['per46', 'norm', '2', '13.png']
# ['per46', 'norm', '3', '3.png']
# ['per46', 'norm', '3', '2.png']
# ['per46', 'norm', '3', '4.png']
# ['per46', 'norm', '3', '5.png']
# ['per46', 'norm', '3', '6.png']
# ['per46', 'norm', '3', '7.png']
# ['per46', 'norm', '3', '8.png']
# ['per75', 'norm', '4', '12.png']
# ['per46', 'norm', '3', '9.png']
# ['per46', 'norm', '3', '10.png']
# ['per46', 'norm', '3', '11.png']
# ['per46', 'norm', '3', '12.png']
# ['per46', 'norm', '3', '13.png']
# ['per46', 'norm', '4', '1.png']
# ['per46', 'norm', '3', '14.png']
# ['per46', 'norm', '4', '2.png']
# ['per46', 'norm', '4', '4.png']
# ['per46', 'norm', '4', '3.png']
# ['per46', 'norm', '4', '5.png']
# ['per46', 'norm', '4', '6.png']
# ['per46', 'norm', '4', '7.png']
# ['per46', 'norm', '4', '8.png']
# ['per46', 'norm', '4', '10.png']
# ['per46', 'norm', '4', '9.png']
# ['per46', 'norm', '4', '11.png']
# ['per46', 'norm', '4', '12.png']
# ['per46', 'norm', '4', '13.png']
# ['per46', 'norm', '4', '14.png']
# ['per46', 'norm', '5', '1.png']
# ['per46', 'norm', '5', '2.png']
# ['per46', 'norm', '5', '3.png']
# ['per46', 'norm', '5', '4.png']
# ['per75', 'norm', '4', '13.png']
# ['per46', 'norm', '5', '5.png']
# ['per46', 'norm', '5', '6.png']
# ['per46', 'norm', '5', '7.png']
# ['per46', 'norm', '5', '8.png']
# ['per46', 'norm', '5', '9.png']
# ['per46', 'norm', '5', '10.png']
# ['per46', 'norm', '5', '11.png']
# ['per46', 'norm', '5', '12.png']
# ['per46', 'norm', '5', '13.png']
# ['per46', 'norm', '5', '14.png']
# ['per46', 'norm', '6', '1.png']
# ['per46', 'norm', '6', '2.png']
# ['per46', 'norm', '6', '3.png']
# ['per46', 'norm', '6', '4.png']
# ['per75', 'norm', '4', '14.png']
# ['per46', 'norm', '6', '5.png']
# ['per46', 'norm', '6', '6.png']
# ['per46', 'norm', '6', '7.png']
# ['per46', 'norm', '6', '8.png']
# ['per46', 'norm', '6', '9.png']
# ['per46', 'norm', '6', '10.png']
# ['per46', 'norm', '6', '11.png']
# ['per46', 'norm', '6', '12.png']
# ['per46', 'norm', '6', '13.png']
# ['per46', 'norm', '6', '14.png']
# ['per46', 'norm', '7', '1.png']
# ['per46', 'norm', '7', '2.png']
# ['per46', 'norm', '7', '3.png']
# ['per46', 'norm', '7', '4.png']
# ['per75', 'norm', '5', '1.png']
# ['per46', 'norm', '7', '5.png']
# ['per46', 'norm', '7', '6.png']
# ['per46', 'norm', '7', '7.png']
# ['per46', 'norm', '7', '8.png']
# ['per46', 'norm', '7', '9.png']
# ['per46', 'norm', '7', '10.png']
# ['per46', 'norm', '7', '11.png']
# ['per46', 'norm', '7', '12.png']
# ['per46', 'norm', '7', '13.png']
# ['per46', 'norm', '7', '14.png']
# ['per46', 'norm', '8', '1.png']
# ['per75', 'norm', '5', '2.png']
# ['per46', 'norm', '8', '2.png']
# ['per46', 'norm', '8', '3.png']
# ['per46', 'norm', '8', '4.png']
# ['per46', 'norm', '8', '5.png']
# ['per46', 'norm', '8', '6.png']
# ['per46', 'norm', '8', '7.png']
# ['per46', 'norm', '8', '8.png']
# ['per46', 'norm', '8', '9.png']
# ['per46', 'norm', '8', '10.png']
# ['per46', 'norm', '8', '11.png']
# ['per46', 'norm', '8', '12.png']
# ['per75', 'norm', '5', '3.png']
# ['per46', 'norm', '8', '13.png']
# ['per46', 'norm', '8', '14.png']
# ['per46', 'norm', '9', '1.png']
# ['per46', 'norm', '9', '2.png']
# ['per46', 'norm', '9', '3.png']
# ['per46', 'norm', '9', '4.png']
# ['per46', 'norm', '9', '5.png']
# ['per46', 'norm', '9', '6.png']
# ['per46', 'norm', '9', '7.png']
# ['per46', 'norm', '9', '8.png']
# ['per75', 'norm', '5', '4.png']
# ['per46', 'norm', '9', '9.png']
# ['per46', 'norm', '9', '10.png']
# ['per46', 'norm', '9', '11.png']
# ['per46', 'norm', '9', '12.png']
# ['per46', 'norm', '9', '13.png']
# ['per46', 'norm', '9', '14.png']
# ['per46', 'norm', '10', '1.png']
# ['per46', 'norm', '10', '2.png']
# ['per46', 'norm', '10', '3.png']
# ['per75', 'norm', '5', '5.png']
# ['per46', 'norm', '10', '4.png']
# ['per46', 'norm', '10', '5.png']
# ['per46', 'norm', '10', '6.png']
# ['per46', 'norm', '10', '7.png']
# ['per46', 'norm', '10', '8.png']
# ['per46', 'norm', '10', '9.png']
# ['per46', 'norm', '10', '10.png']
# ['per46', 'norm', '10', '11.png']
# ['per75', 'norm', '5', '6.png']
# ['per46', 'norm', '10', '12.png']
# ['per46', 'norm', '10', '13.png']
# ['per46', 'norm', '10', '14.png']
# ['per46', 'norm', '11', '1.png']
# ['per46', 'norm', '11', '2.png']
# ['per46', 'norm', '11', '3.png']
# ['per46', 'norm', '11', '4.png']
# ['per75', 'norm', '5', '7.png']
# ['per46', 'norm', '11', '5.png']
# ['per46', 'norm', '11', '6.png']
# ['per46', 'norm', '11', '7.png']
# ['per46', 'norm', '11', '8.png']
# ['per46', 'norm', '11', '9.png']
# ['per46', 'norm', '11', '10.png']
# ['per46', 'norm', '11', '11.png']
# ['per46', 'norm', '11', '12.png']
# ['per75', 'norm', '5', '8.png']
# ['per46', 'norm', '11', '13.png']
# ['per46', 'norm', '11', '14.png']
# ['per46', 'norm', '12', '1.png']
# ['per46', 'norm', '12', '2.png']
# ['per46', 'norm', '12', '3.png']
# ['per46', 'norm', '12', '4.png']
# ['per46', 'norm', '12', '5.png']
# ['per75', 'norm', '5', '9.png']
# ['per46', 'norm', '12', '6.png']
# ['per46', 'norm', '12', '7.png']
# ['per46', 'norm', '12', '8.png']
# ['per46', 'norm', '12', '9.png']
# ['per46', 'norm', '12', '10.png']
# ['per46', 'norm', '12', '11.png']
# ['per75', 'norm', '5', '10.png']
# ['per46', 'norm', '12', '12.png']
# ['per46', 'norm', '12', '13.png']
# ['per46', 'norm', '12', '14.png']
# ['per46', 'norm', '13', '1.png']
# ['per46', 'norm', '13', '2.png']
# ['per46', 'norm', '13', '3.png']
# ['per46', 'norm', '13', '4.png']
# ['per75', 'norm', '5', '11.png']
# ['per46', 'norm', '13', '5.png']
# ['per46', 'norm', '13', '6.png']
# ['per46', 'norm', '13', '7.png']
# ['per46', 'norm', '13', '8.png']
# ['per46', 'norm', '13', '9.png']
# ['per46', 'norm', '13', '10.png']
# ['per75', 'norm', '5', '12.png']
# ['per46', 'norm', '13', '11.png']
# ['per46', 'norm', '13', '12.png']
# ['per46', 'norm', '13', '13.png']
# ['per46', 'norm', '13', '14.png']
# ['per46', 'norm', '14', '1.png']
# ['per46', 'norm', '14', '2.png']
# ['per46', 'norm', '14', '3.png']
# ['per75', 'norm', '5', '13.png']
# ['per46', 'norm', '14', '4.png']
# ['per46', 'norm', '14', '5.png']
# ['per46', 'norm', '14', '6.png']
# ['per46', 'norm', '14', '7.png']
# ['per46', 'norm', '14', '8.png']
# ['per75', 'norm', '5', '14.png']
# ['per46', 'norm', '14', '9.png']
# ['per46', 'norm', '14', '10.png']
# ['per46', 'norm', '14', '11.png']
# ['per46', 'norm', '14', '12.png']
# ['per46', 'norm', '14', '13.png']
# ['per46', 'norm', '14', '14.png']
# ['per46', 'norm', '15', '1.png']
# ['per75', 'norm', '6', '1.png']
# ['per46', 'norm', '15', '2.png']
# ['per46', 'norm', '15', '3.png']
# ['per46', 'norm', '15', '4.png']
# ['per46', 'norm', '15', '5.png']
# ['per46', 'norm', '15', '6.png']
# ['per75', 'norm', '6', '2.png']
# ['per46', 'norm', '15', '7.png']
# ['per46', 'norm', '15', '8.png']
# ['per46', 'norm', '15', '9.png']
# ['per72', 'norm', '14', '3.png']
# ['per72', 'norm', '14', '4.png']
# ['per39', 'schiz', '15', '14.png']
# ['per72', 'norm', '14', '5.png']
# ['per39', 'schiz', '16', '1.png']
# ['per72', 'norm', '14', '6.png']
# ['per39', 'schiz', '16', '2.png']
# ['per72', 'norm', '14', '7.png']
# ['per39', 'schiz', '16', '3.png']
# ['per72', 'norm', '14', '8.png']
# ['per39', 'schiz', '16', '4.png']
# ['per72', 'norm', '14', '9.png']
# ['per39', 'schiz', '16', '5.png']
# ['per72', 'norm', '14', '10.png']
# ['per39', 'schiz', '16', '6.png']
# ['per72', 'norm', '14', '11.png']
# ['per39', 'schiz', '16', '7.png']
# ['per72', 'norm', '14', '12.png']
# ['per39', 'schiz', '16', '8.png']
# ['per72', 'norm', '14', '13.png']
# ['per39', 'schiz', '16', '9.png']
# ['per72', 'norm', '14', '14.png']
# ['per39', 'schiz', '16', '10.png']
# ['per72', 'norm', '15', '1.png']
# ['per39', 'schiz', '16', '11.png']
# ['per72', 'norm', '15', '2.png']
# ['per39', 'schiz', '16', '12.png']
# ['per72', 'norm', '15', '3.png']
# ['per39', 'schiz', '16', '13.png']
# ['per72', 'norm', '15', '4.png']
# ['per39', 'schiz', '16', '14.png']
# ['per72', 'norm', '15', '5.png']
# ['per40', 'schiz', '1', '1.png']
# ['per72', 'norm', '15', '6.png']
# ['per40', 'schiz', '1', '2.png']
# ['per72', 'norm', '15', '7.png']
# ['per40', 'schiz', '1', '3.png']
# ['per72', 'norm', '15', '8.png']
# ['per40', 'schiz', '1', '4.png']
# ['per72', 'norm', '15', '9.png']
# ['per40', 'schiz', '1', '5.png']
# ['per72', 'norm', '15', '10.png']
# ['per40', 'schiz', '1', '6.png']
# ['per72', 'norm', '15', '11.png']
# ['per40', 'schiz', '1', '7.png']
# ['per72', 'norm', '15', '12.png']
# ['per72', 'norm', '15', '13.png']
# ['per40', 'schiz', '1', '8.png']
# ['per40', 'schiz', '1', '9.png']
# ['per72', 'norm', '15', '14.png']
# ['per40', 'schiz', '1', '10.png']
# ['per72', 'norm', '16', '1.png']
# ['per72', 'norm', '16', '2.png']
# ['per40', 'schiz', '1', '11.png']
# ['per72', 'norm', '16', '3.png']
# ['per40', 'schiz', '1', '12.png']
# ['per72', 'norm', '16', '4.png']
# ['per40', 'schiz', '1', '13.png']
# ['per72', 'norm', '16', '5.png']
# ['per40', 'schiz', '1', '14.png']
# ['per72', 'norm', '16', '6.png']
# ['per40', 'schiz', '2', '1.png']
# ['per72', 'norm', '16', '7.png']
# ['per40', 'schiz', '2', '2.png']
# ['per72', 'norm', '16', '8.png']
# ['per40', 'schiz', '2', '3.png']
# ['per72', 'norm', '16', '9.png']
# ['per40', 'schiz', '2', '4.png']
# ['per72', 'norm', '16', '10.png']
# ['per40', 'schiz', '2', '5.png']
# ['per72', 'norm', '16', '11.png']
# ['per40', 'schiz', '2', '6.png']
# ['per72', 'norm', '16', '12.png']
# ['per40', 'schiz', '2', '7.png']
# ['per72', 'norm', '16', '13.png']
# ['per40', 'schiz', '2', '8.png']
# ['per72', 'norm', '16', '14.png']
# ['per40', 'schiz', '2', '9.png']
# ['per73', 'norm', '1', '1.png']
# ['per40', 'schiz', '2', '10.png']
# ['per73', 'norm', '1', '2.png']
# ['per40', 'schiz', '2', '11.png']
# ['per73', 'norm', '1', '3.png']
# ['per40', 'schiz', '2', '12.png']
# ['per73', 'norm', '1', '4.png']
# ['per40', 'schiz', '2', '13.png']
# ['per73', 'norm', '1', '5.png']
# ['per40', 'schiz', '2', '14.png']
# ['per73', 'norm', '1', '6.png']
# ['per40', 'schiz', '3', '1.png']
# ['per73', 'norm', '1', '7.png']
# ['per40', 'schiz', '3', '2.png']
# ['per73', 'norm', '1', '8.png']
# ['per40', 'schiz', '3', '3.png']
# ['per73', 'norm', '1', '9.png']
# ['per40', 'schiz', '3', '4.png']
# ['per73', 'norm', '1', '10.png']
# ['per40', 'schiz', '3', '5.png']
# ['per73', 'norm', '1', '11.png']
# ['per40', 'schiz', '3', '6.png']
# ['per73', 'norm', '1', '12.png']
# ['per73', 'norm', '1', '13.png']
# ['per40', 'schiz', '3', '7.png']
# ['per73', 'norm', '1', '14.png']
# ['per40', 'schiz', '3', '8.png']
# ['per73', 'norm', '2', '1.png']
# ['per40', 'schiz', '3', '9.png']
# ['per73', 'norm', '2', '2.png']
# ['per40', 'schiz', '3', '10.png']
# ['per73', 'norm', '2', '3.png']
# ['per40', 'schiz', '3', '11.png']
# ['per73', 'norm', '2', '4.png']
# ['per40', 'schiz', '3', '12.png']
# ['per73', 'norm', '2', '5.png']
# ['per40', 'schiz', '3', '13.png']
# ['per73', 'norm', '2', '6.png']
# ['per40', 'schiz', '3', '14.png']
# ['per73', 'norm', '2', '7.png']
# ['per40', 'schiz', '4', '1.png']
# ['per73', 'norm', '2', '8.png']
# ['per40', 'schiz', '4', '2.png']
# ['per73', 'norm', '2', '9.png']
# ['per40', 'schiz', '4', '3.png']
# ['per73', 'norm', '2', '10.png']
# ['per40', 'schiz', '4', '4.png']
# ['per73', 'norm', '2', '11.png']
# ['per40', 'schiz', '4', '5.png']
# ['per73', 'norm', '2', '12.png']
# ['per40', 'schiz', '4', '6.png']
# ['per73', 'norm', '2', '13.png']
# ['per40', 'schiz', '4', '7.png']
# ['per73', 'norm', '2', '14.png']
# ['per40', 'schiz', '4', '8.png']
# ['per73', 'norm', '3', '1.png']
# ['per40', 'schiz', '4', '9.png']
# ['per73', 'norm', '3', '2.png']
# ['per40', 'schiz', '4', '10.png']
# ['per73', 'norm', '3', '3.png']
# ['per40', 'schiz', '4', '11.png']
# ['per73', 'norm', '3', '4.png']
# ['per73', 'norm', '3', '5.png']
# ['per40', 'schiz', '4', '12.png']
# ['per73', 'norm', '3', '6.png']
# ['per40', 'schiz', '4', '13.png']
# ['per73', 'norm', '3', '7.png']
# ['per40', 'schiz', '4', '14.png']
# ['per73', 'norm', '3', '8.png']
# ['per40', 'schiz', '5', '1.png']
# ['per73', 'norm', '3', '9.png']
# ['per40', 'schiz', '5', '2.png']
# ['per73', 'norm', '3', '10.png']
# ['per40', 'schiz', '5', '3.png']
# ['per73', 'norm', '3', '11.png']
# ['per40', 'schiz', '5', '4.png']
# ['per73', 'norm', '3', '12.png']
# ['per40', 'schiz', '5', '5.png']
# ['per73', 'norm', '3', '13.png']
# ['per40', 'schiz', '5', '6.png']
# ['per73', 'norm', '3', '14.png']
# ['per40', 'schiz', '5', '7.png']
# ['per73', 'norm', '4', '1.png']
# ['per40', 'schiz', '5', '8.png']
# ['per73', 'norm', '4', '2.png']
# ['per40', 'schiz', '5', '9.png']
# ['per73', 'norm', '4', '3.png']
# ['per40', 'schiz', '5', '10.png']
# ['per73', 'norm', '4', '4.png']
# ['per40', 'schiz', '5', '11.png']
# ['per73', 'norm', '4', '5.png']
# ['per40', 'schiz', '5', '12.png']
# ['per73', 'norm', '4', '6.png']
# ['per40', 'schiz', '5', '13.png']
# ['per73', 'norm', '4', '7.png']
# ['per40', 'schiz', '5', '14.png']
# ['per73', 'norm', '4', '8.png']
# ['per40', 'schiz', '6', '1.png']
# ['per73', 'norm', '4', '9.png']
# ['per40', 'schiz', '6', '2.png']
# ['per73', 'norm', '4', '10.png']
# ['per40', 'schiz', '6', '3.png']
# ['per73', 'norm', '4', '11.png']
# ['per73', 'norm', '4', '12.png']
# ['per40', 'schiz', '6', '4.png']
# ['per73', 'norm', '4', '13.png']
# ['per40', 'schiz', '6', '5.png']
# ['per73', 'norm', '4', '14.png']
# ['per40', 'schiz', '6', '6.png']
# ['per73', 'norm', '5', '1.png']
# ['per40', 'schiz', '6', '7.png']
# ['per73', 'norm', '5', '2.png']
# ['per40', 'schiz', '6', '8.png']
# ['per73', 'norm', '5', '3.png']
# ['per40', 'schiz', '6', '9.png']
# ['per73', 'norm', '5', '4.png']
# ['per40', 'schiz', '6', '10.png']
# ['per73', 'norm', '5', '5.png']
# ['per40', 'schiz', '6', '11.png']
# ['per73', 'norm', '5', '6.png']
# ['per40', 'schiz', '6', '12.png']
# ['per73', 'norm', '5', '7.png']
# ['per40', 'schiz', '6', '13.png']
# ['per73', 'norm', '5', '8.png']
# ['per40', 'schiz', '6', '14.png']
# ['per73', 'norm', '5', '9.png']
# ['per40', 'schiz', '7', '1.png']
# ['per73', 'norm', '5', '10.png']
# ['per40', 'schiz', '7', '2.png']
# ['per73', 'norm', '5', '11.png']
# ['per40', 'schiz', '7', '3.png']
# ['per73', 'norm', '5', '12.png']
# ['per40', 'schiz', '7', '4.png']
# ['per73', 'norm', '5', '13.png']
# ['per40', 'schiz', '7', '5.png']
# ['per73', 'norm', '5', '14.png']
# ['per40', 'schiz', '7', '6.png']
# ['per73', 'norm', '6', '1.png']
# ['per73', 'norm', '6', '2.png']
# ['per40', 'schiz', '7', '7.png']
# ['per40', 'schiz', '7', '8.png']
# ['per73', 'norm', '6', '3.png']
# ['per73', 'norm', '6', '4.png']
# ['per40', 'schiz', '7', '9.png']
# ['per73', 'norm', '6', '5.png']
# ['per40', 'schiz', '7', '10.png']
# ['per73', 'norm', '6', '6.png']
# ['per40', 'schiz', '7', '11.png']
# ['per73', 'norm', '6', '7.png']
# ['per40', 'schiz', '7', '12.png']
# ['per73', 'norm', '6', '8.png']
# ['per40', 'schiz', '7', '13.png']
# ['per73', 'norm', '6', '9.png']
# ['per40', 'schiz', '7', '14.png']
# ['per73', 'norm', '6', '10.png']
# ['per73', 'norm', '6', '11.png']
# ['per73', 'norm', '6', '12.png']
# ['per73', 'norm', '6', '13.png']
# ['per73', 'norm', '6', '14.png']
# ['per73', 'norm', '7', '1.png']
# ['per73', 'norm', '7', '2.png']
# ['per73', 'norm', '7', '3.png']
# ['per73', 'norm', '7', '4.png']
# ['per73', 'norm', '7', '5.png']
# ['per73', 'norm', '7', '6.png']
# ['per73', 'norm', '7', '7.png']
# ['per73', 'norm', '7', '8.png']
# ['per73', 'norm', '7', '9.png']
# ['per73', 'norm', '7', '10.png']
# ['per73', 'norm', '7', '11.png']
# ['per73', 'norm', '7', '12.png']
# ['per73', 'norm', '7', '13.png']
# ['per73', 'norm', '7', '14.png']
# ['per73', 'norm', '8', '1.png']
# ['per73', 'norm', '8', '2.png']
# ['per73', 'norm', '8', '3.png']
# ['per73', 'norm', '8', '4.png']
# ['per73', 'norm', '8', '5.png']
# ['per73', 'norm', '8', '6.png']
# ['per73', 'norm', '8', '7.png']
# ['per73', 'norm', '8', '8.png']
# ['per41', 'schiz', '1', '9.png']
# ['per41', 'schiz', '1', '1.png']
# ['per41', 'schiz', '1', '6.png']
# ['per41', 'schiz', '1', '5.png']
# ['per41', 'schiz', '1', '10.png']
# ['per41', 'schiz', '1', '8.png']
# ['per41', 'schiz', '1', '4.png']
# ['per41', 'schiz', '1', '3.png']
# ['per41', 'schiz', '1', '2.png']
# ['per41', 'schiz', '1', '7.png']
# ['per41', 'schiz', '1', '13.png']
# ['per41', 'schiz', '1', '11.png']
# ['per41', 'schiz', '1', '12.png']
# ['per41', 'schiz', '1', '14.png']
# ['per41', 'schiz', '2', '1.png']
# ['per41', 'schiz', '2', '2.png']
# ['per41', 'schiz', '2', '4.png']
# ['per41', 'schiz', '2', '3.png']
# ['per41', 'schiz', '2', '5.png']
# ['per73', 'norm', '8', '9.png']
# ['per41', 'schiz', '2', '7.png']
# ['per41', 'schiz', '2', '8.png']
# ['per41', 'schiz', '2', '6.png']
# ['per41', 'schiz', '2', '9.png']
# ['per41', 'schiz', '2', '11.png']
# ['per41', 'schiz', '2', '10.png']
# ['per41', 'schiz', '2', '14.png']
# ['per41', 'schiz', '2', '12.png']
# ...
# ['per2', 'schiz', '11', '2.png']
# ['per2', 'schiz', '11', '3.png']
# ['per2', 'schiz', '11', '4.png']
# ['per2', 'schiz', '11', '5.png']
# ['per2', 'schiz', '11', '6.png']
# ['per2', 'schiz', '11', '7.png']
# ['per2', 'schiz', '11', '8.png']
# ['per2', 'schiz', '11', '9.png']
# ['per2', 'schiz', '11', '10.png']
# ['per2', 'schiz', '11', '11.png']
# ['per2', 'schiz', '11', '12.png']
# ['per2', 'schiz', '11', '13.png']
# ['per2', 'schiz', '11', '14.png']
# ['per2', 'schiz', '12', '1.png']
# ['per2', 'schiz', '12', '2.png']
# ['per2', 'schiz', '12', '3.png']
# ['per2', 'schiz', '12', '4.png']
# ['per2', 'schiz', '12', '5.png']
# ['per2', 'schiz', '12', '6.png']
# ['per2', 'schiz', '12', '7.png']
# ['per2', 'schiz', '12', '8.png']
# ['per2', 'schiz', '12', '9.png']
# ['per2', 'schiz', '12', '10.png']
# ['per2', 'schiz', '12', '11.png']
# ['per2', 'schiz', '12', '12.png']
# ['per2', 'schiz', '12', '13.png']
# ['per2', 'schiz', '12', '14.png']
# ['per2', 'schiz', '13', '1.png']
# ['per2', 'schiz', '13', '2.png']
# ['per2', 'schiz', '13', '3.png']
# ['per2', 'schiz', '13', '4.png']
# ['per2', 'schiz', '13', '5.png']
# ['per2', 'schiz', '13', '6.png']
# ['per2', 'schiz', '13', '7.png']
# ['per2', 'schiz', '13', '8.png']
# ['per2', 'schiz', '13', '9.png']
# ['per2', 'schiz', '13', '10.png']
# ['per2', 'schiz', '13', '11.png']
# ['per2', 'schiz', '13', '12.png']
# ['per2', 'schiz', '13', '13.png']
# ['per2', 'schiz', '13', '14.png']
# ['per2', 'schiz', '14', '1.png']
# ['per2', 'schiz', '14', '2.png']
# ['per2', 'schiz', '14', '3.png']
# ['per2', 'schiz', '14', '4.png']
# ['per2', 'schiz', '14', '5.png']
# ['per2', 'schiz', '14', '6.png']
# ['per2', 'schiz', '14', '7.png']
# ['per2', 'schiz', '14', '8.png']
# ['per2', 'schiz', '14', '9.png']
# ['per2', 'schiz', '14', '10.png']
# ['per2', 'schiz', '14', '11.png']
# ['per2', 'schiz', '14', '12.png']
# ['per2', 'schiz', '14', '13.png']
# ['per2', 'schiz', '14', '14.png']
# ['per2', 'schiz', '15', '1.png']
# ['per2', 'schiz', '15', '2.png']
# ['per2', 'schiz', '15', '3.png']
# ['per2', 'schiz', '15', '4.png']
# ['per2', 'schiz', '15', '5.png']
# ['per2', 'schiz', '15', '6.png']
# ['per2', 'schiz', '15', '7.png']
# ['per2', 'schiz', '15', '8.png']
# ['per2', 'schiz', '15', '9.png']
# ['per2', 'schiz', '15', '10.png']
# ['per2', 'schiz', '15', '11.png']
# ['per2', 'schiz', '15', '12.png']
# ['per2', 'schiz', '15', '13.png']
# ['per2', 'schiz', '15', '14.png']
# ['per2', 'schiz', '16', '1.png']
# ['per2', 'schiz', '16', '2.png']
# ['per2', 'schiz', '16', '3.png']
# ['per2', 'schiz', '16', '4.png']
# ['per2', 'schiz', '16', '5.png']
# ['per2', 'schiz', '16', '6.png']
# ['per2', 'schiz', '16', '7.png']
# ['per2', 'schiz', '16', '8.png']
# ['per2', 'schiz', '16', '9.png']
# ['per2', 'schiz', '16', '10.png']
# ['per2', 'schiz', '16', '11.png']
# ['per2', 'schiz', '16', '12.png']
# ['per2', 'schiz', '16', '13.png']
# ['per2', 'schiz', '16', '14.png']
# ['per3', 'schiz', '1', '1.png']
# ['per3', 'schiz', '1', '2.png']
# ['per3', 'schiz', '1', '3.png']
# ['per3', 'schiz', '1', '4.png']
# ['per3', 'schiz', '1', '5.png']
# ['per3', 'schiz', '1', '6.png']
# ['per3', 'schiz', '1', '7.png']
# ['per3', 'schiz', '1', '8.png']
# ['per3', 'schiz', '1', '9.png']
# ['per3', 'schiz', '1', '10.png']
# ['per3', 'schiz', '1', '11.png']
# ['per3', 'schiz', '1', '12.png']
# ['per3', 'schiz', '1', '13.png']
# ['per3', 'schiz', '1', '14.png']
# ['per3', 'schiz', '2', '1.png']
# ['per3', 'schiz', '2', '2.png']
# ['per3', 'schiz', '2', '3.png']
# ['per3', 'schiz', '2', '4.png']
# ['per3', 'schiz', '2', '5.png']
# ['per3', 'schiz', '2', '6.png']
# ['per3', 'schiz', '2', '7.png']
# ['per3', 'schiz', '2', '8.png']
# ['per3', 'schiz', '2', '9.png']
# ['per3', 'schiz', '2', '10.png']
# ['per3', 'schiz', '2', '11.png']
# ['per3', 'schiz', '2', '12.png']
# ['per3', 'schiz', '2', '13.png']
# ['per3', 'schiz', '2', '14.png']
# ['per3', 'schiz', '3', '1.png']
# ['per3', 'schiz', '3', '2.png']
# ['per3', 'schiz', '3', '3.png']
# ['per3', 'schiz', '3', '4.png']
# ['per3', 'schiz', '3', '5.png']
# ['per3', 'schiz', '3', '6.png']
# ['per3', 'schiz', '3', '7.png']
# ['per3', 'schiz', '3', '8.png']
# ['per3', 'schiz', '3', '9.png']
# ['per3', 'schiz', '3', '10.png']
# ['per3', 'schiz', '3', '11.png']
# ['per3', 'schiz', '3', '12.png']
# ['per3', 'schiz', '3', '13.png']
# ['per3', 'schiz', '3', '14.png']
# ['per3', 'schiz', '4', '1.png']
# ['per3', 'schiz', '4', '2.png']
# ['per3', 'schiz', '4', '3.png']
# ['per3', 'schiz', '4', '4.png']
# ['per3', 'schiz', '4', '5.png']
# ['per3', 'schiz', '4', '6.png']
# ['per3', 'schiz', '4', '7.png']
# ['per3', 'schiz', '4', '8.png']
# ['per3', 'schiz', '4', '9.png']
# ['per3', 'schiz', '4', '10.png']
# ['per3', 'schiz', '4', '11.png']
# ['per3', 'schiz', '4', '12.png']
# ['per3', 'schiz', '4', '13.png']
# ['per3', 'schiz', '4', '14.png']
# ['per3', 'schiz', '5', '1.png']
# ['per3', 'schiz', '5', '2.png']
# ['per3', 'schiz', '5', '3.png']
# ['per3', 'schiz', '5', '4.png']
# ['per3', 'schiz', '5', '5.png']
# ['per3', 'schiz', '5', '6.png']
# ['per3', 'schiz', '5', '7.png']
# ['per3', 'schiz', '5', '8.png']
# ['per3', 'schiz', '5', '9.png']
# ['per3', 'schiz', '5', '10.png']
# ['per3', 'schiz', '5', '11.png']
# ['per3', 'schiz', '5', '12.png']
# ['per3', 'schiz', '5', '13.png']
# ['per3', 'schiz', '5', '14.png']
# ['per3', 'schiz', '6', '1.png']
# ['per3', 'schiz', '6', '2.png']
# ['per3', 'schiz', '6', '3.png']
# ['per3', 'schiz', '6', '4.png']
# ['per3', 'schiz', '6', '5.png']
# ['per3', 'schiz', '6', '6.png']
# ['per3', 'schiz', '6', '7.png']
# ['per3', 'schiz', '6', '8.png']
# ['per3', 'schiz', '6', '9.png']
# ['per3', 'schiz', '6', '10.png']
# ['per3', 'schiz', '6', '11.png']
# ['per3', 'schiz', '6', '12.png']
# ['per3', 'schiz', '6', '13.png']
# ['per3', 'schiz', '6', '14.png']
# ['per3', 'schiz', '7', '1.png']
# ['per3', 'schiz', '7', '2.png']
# ['per3', 'schiz', '7', '3.png']
# ['per3', 'schiz', '7', '4.png']
# ['per3', 'schiz', '7', '5.png']
# ['per3', 'schiz', '7', '6.png']
# ['per3', 'schiz', '7', '7.png']
# ['per3', 'schiz', '7', '8.png']
# ['per3', 'schiz', '7', '9.png']
# ['per3', 'schiz', '7', '10.png']
# ['per3', 'schiz', '7', '11.png']
# ['per3', 'schiz', '7', '12.png']
# ['per3', 'schiz', '7', '13.png']
# ['per3', 'schiz', '7', '14.png']
# ['per3', 'schiz', '8', '1.png']
# ['per3', 'schiz', '8', '2.png']
# ['per3', 'schiz', '8', '3.png']
# ['per3', 'schiz', '8', '4.png']
# ['per3', 'schiz', '8', '5.png']
# ['per3', 'schiz', '8', '6.png']
# ['per3', 'schiz', '8', '7.png']
# ['per3', 'schiz', '8', '8.png']
# ['per3', 'schiz', '8', '9.png']
# ['per3', 'schiz', '8', '10.png']
# ['per3', 'schiz', '8', '11.png']
# ['per3', 'schiz', '8', '12.png']
# ['per3', 'schiz', '8', '13.png']
# ['per3', 'schiz', '8', '14.png']
# ['per3', 'schiz', '9', '1.png']
# ['per3', 'schiz', '9', '2.png']
# ['per3', 'schiz', '9', '3.png']
# ['per3', 'schiz', '9', '4.png']
# ['per3', 'schiz', '9', '5.png']
# ['per3', 'schiz', '9', '6.png']
# ['per3', 'schiz', '9', '7.png']
# ['per3', 'schiz', '9', '8.png']
# ['per3', 'schiz', '9', '9.png']
# ['per3', 'schiz', '9', '10.png']
# ['per3', 'schiz', '9', '11.png']
# ['per3', 'schiz', '9', '12.png']
# ['per3', 'schiz', '9', '13.png']
# ['per3', 'schiz', '9', '14.png']
# ['per3', 'schiz', '10', '1.png']
# ['per3', 'schiz', '10', '2.png']
# ['per3', 'schiz', '10', '3.png']
# ['per3', 'schiz', '10', '4.png']
# ['per3', 'schiz', '10', '5.png']
# ['per3', 'schiz', '10', '6.png']
# ['per3', 'schiz', '10', '7.png']
# ['per3', 'schiz', '10', '8.png']
# ['per3', 'schiz', '10', '9.png']
# ['per3', 'schiz', '10', '10.png']
# ['per3', 'schiz', '10', '11.png']
# ['per3', 'schiz', '10', '12.png']
# ['per3', 'schiz', '10', '13.png']
# ['per3', 'schiz', '10', '14.png']
# ['per3', 'schiz', '11', '1.png']
# ['per3', 'schiz', '11', '2.png']
# ['per3', 'schiz', '11', '3.png']
# ['per3', 'schiz', '11', '4.png']
# ['per3', 'schiz', '11', '5.png']
# ['per3', 'schiz', '11', '6.png']
# ['per3', 'schiz', '11', '7.png']
# ['per3', 'schiz', '11', '8.png']
# ['per3', 'schiz', '11', '9.png']
# ['per3', 'schiz', '11', '10.png']
# ['per3', 'schiz', '11', '11.png']
# ['per3', 'schiz', '11', '12.png']
# ['per3', 'schiz', '11', '13.png']
# ['per3', 'schiz', '11', '14.png']
# ['per3', 'schiz', '12', '1.png']
# ['per3', 'schiz', '12', '2.png']
# ['per3', 'schiz', '12', '3.png']
# ['per3', 'schiz', '12', '4.png']
# ['per3', 'schiz', '12', '5.png']
# ['per3', 'schiz', '12', '6.png']
# ['per3', 'schiz', '12', '7.png']
# ['per3', 'schiz', '12', '8.png']
# ['per3', 'schiz', '12', '9.png']
# ['per3', 'schiz', '12', '10.png']
# ['per3', 'schiz', '12', '11.png']
# ['per3', 'schiz', '12', '12.png']
# ['per3', 'schiz', '12', '13.png']
# ['per3', 'schiz', '12', '14.png']
# ['per3', 'schiz', '13', '1.png']
# ['per3', 'schiz', '13', '2.png']
# ['per3', 'schiz', '13', '3.png']
# ['per3', 'schiz', '13', '4.png']
# ['per3', 'schiz', '13', '5.png']
# ['per3', 'schiz', '13', '6.png']
# ['per3', 'schiz', '13', '7.png']
# ['per3', 'schiz', '13', '8.png']
# ['per3', 'schiz', '13', '9.png']
# ['per3', 'schiz', '13', '10.png']
# ['per3', 'schiz', '13', '11.png']
# ['per3', 'schiz', '13', '12.png']
# ['per3', 'schiz', '13', '13.png']
# ['per3', 'schiz', '13', '14.png']
# ['per3', 'schiz', '14', '1.png']
# ['per3', 'schiz', '14', '2.png']
# ['per3', 'schiz', '14', '3.png']
# ['per3', 'schiz', '14', '4.png']
# ['per3', 'schiz', '14', '5.png']
# ['per3', 'schiz', '14', '6.png']
# ['per3', 'schiz', '14', '7.png']
# ['per3', 'schiz', '14', '8.png']
# ['per3', 'schiz', '14', '9.png']
# ['per3', 'schiz', '14', '10.png']
# ['per3', 'schiz', '14', '11.png']
# ['per3', 'schiz', '14', '12.png']
# ['per3', 'schiz', '14', '13.png']
# ['per3', 'schiz', '14', '14.png']
# ['per3', 'schiz', '15', '1.png']
# ['per3', 'schiz', '15', '2.png']
# ['per3', 'schiz', '15', '3.png']
# ['per3', 'schiz', '15', '4.png']
# ['per3', 'schiz', '15', '5.png']
# ['per3', 'schiz', '15', '6.png']
# ['per3', 'schiz', '15', '7.png']
# ['per3', 'schiz', '15', '8.png']
# ['per3', 'schiz', '15', '9.png']
# ['per3', 'schiz', '15', '10.png']
# ['per3', 'schiz', '15', '11.png']
# ['per3', 'schiz', '15', '12.png']
# ['per3', 'schiz', '15', '13.png']
# ['per3', 'schiz', '15', '14.png']
# ['per3', 'schiz', '16', '1.png']
# ['per3', 'schiz', '16', '2.png']
# ['per3', 'schiz', '16', '3.png']
# ['per3', 'schiz', '16', '4.png']
# ['per3', 'schiz', '16', '5.png']
# ['per3', 'schiz', '16', '6.png']
# ['per3', 'schiz', '16', '7.png']
# ['per3', 'schiz', '16', '8.png']
# ['per3', 'schiz', '16', '9.png']
# ['per3', 'schiz', '16', '10.png']
# ['per3', 'schiz', '16', '11.png']
# ['per3', 'schiz', '16', '12.png']
# ['per3', 'schiz', '16', '13.png']
# ['per3', 'schiz', '16', '14.png']
# ['per31', 'schiz', '1', '1.png']
# ['per31', 'schiz', '1', '5.png']
# ['per31', 'schiz', '1', '3.png']
# ['per31', 'schiz', '1', '9.png']
# ['per31', 'schiz', '1', '6.png']
# ['per31', 'schiz', '1', '8.png']
# ['per31', 'schiz', '1', '10.png']
# ['per31', 'schiz', '1', '2.png']
# ['per31', 'schiz', '1', '4.png']
# ['per31', 'schiz', '1', '7.png']
# ['per31', 'schiz', '1', '14.png']
# ['per31', 'schiz', '1', '12.png']
# ['per31', 'schiz', '1', '11.png']
# ['per31', 'schiz', '1', '13.png']
# ['per31', 'schiz', '2', '1.png']
# ['per31', 'schiz', '2', '2.png']
# ['per31', 'schiz', '2', '3.png']
# ['per31', 'schiz', '2', '4.png']
# ['per31', 'schiz', '2', '5.png']
# ['per31', 'schiz', '2', '7.png']
# ['per31', 'schiz', '2', '6.png']
# ['per31', 'schiz', '2', '9.png']
# ['per31', 'schiz', '2', '10.png']
# ['per31', 'schiz', '2', '8.png']
# ['per31', 'schiz', '2', '12.png']
# ['per31', 'schiz', '2', '13.png']
# ['per31', 'schiz', '2', '11.png']
# ['per31', 'schiz', '2', '14.png']
# ['per31', 'schiz', '3', '1.png']
# ['per31', 'schiz', '3', '2.png']
# ['per31', 'schiz', '3', '3.png']
# ['per31', 'schiz', '3', '4.png']
# ['per31', 'schiz', '3', '6.png']
# ['per31', 'schiz', '3', '5.png']
# ['per31', 'schiz', '3', '8.png']
# ['per31', 'schiz', '3', '7.png']
# ['per31', 'schiz', '3', '10.png']
# ['per31', 'schiz', '3', '9.png']
# ['per31', 'schiz', '3', '12.png']
# ['per31', 'schiz', '3', '11.png']
# ['per31', 'schiz', '3', '13.png']
# ['per31', 'schiz', '3', '14.png']
# ['per31', 'schiz', '4', '1.png']
# ['per31', 'schiz', '4', '2.png']
# ['per31', 'schiz', '4', '4.png']
# ['per31', 'schiz', '4', '3.png']
# ['per31', 'schiz', '4', '5.png']
# ['per31', 'schiz', '4', '6.png']
# ['per31', 'schiz', '4', '7.png']
# ['per31', 'schiz', '4', '8.png']
# ['per31', 'schiz', '4', '9.png']
# ['per31', 'schiz', '4', '11.png']
# ['per31', 'schiz', '4', '10.png']
# ['per31', 'schiz', '4', '12.png']
# ['per31', 'schiz', '4', '13.png']
# ['per31', 'schiz', '4', '14.png']
# ['per31', 'schiz', '5', '1.png']
# ['per31', 'schiz', '5', '2.png']
# ['per31', 'schiz', '5', '4.png']
# ['per31', 'schiz', '5', '3.png']
# ['per31', 'schiz', '5', '5.png']
# ['per31', 'schiz', '5', '6.png']
# ['per31', 'schiz', '5', '7.png']
# ['per31', 'schiz', '5', '8.png']
# ['per31', 'schiz', '5', '9.png']
# ['per31', 'schiz', '5', '10.png']
# ['per31', 'schiz', '5', '11.png']
# ['per31', 'schiz', '5', '12.png']
# ['per31', 'schiz', '5', '13.png']
# ['per31', 'schiz', '5', '14.png']
# ['per31', 'schiz', '6', '1.png']
# ['per31', 'schiz', '6', '2.png']
# ['per31', 'schiz', '6', '3.png']
# ['per31', 'schiz', '6', '4.png']
# ['per31', 'schiz', '6', '5.png']
# ['per31', 'schiz', '6', '6.png']
# ['per31', 'schiz', '6', '7.png']
# ['per31', 'schiz', '6', '8.png']
# ['per31', 'schiz', '6', '9.png']
# ['per31', 'schiz', '6', '10.png']
# ['per31', 'schiz', '6', '11.png']
# ['per31', 'schiz', '6', '12.png']
# ['per31', 'schiz', '6', '13.png']
# ['per31', 'schiz', '6', '14.png']
# ['per31', 'schiz', '7', '1.png']
# ['per31', 'schiz', '7', '2.png']
# ['per31', 'schiz', '7', '3.png']
# ['per31', 'schiz', '7', '4.png']
# ['per31', 'schiz', '7', '5.png']
# ['per31', 'schiz', '7', '6.png']
# ['per31', 'schiz', '7', '7.png']
# ['per31', 'schiz', '7', '8.png']
# ['per31', 'schiz', '7', '9.png']
# ['per31', 'schiz', '7', '10.png']
# ['per31', 'schiz', '7', '11.png']
# ['per31', 'schiz', '7', '12.png']
# ['per31', 'schiz', '7', '13.png']
# ['per31', 'schiz', '7', '14.png']
# ['per31', 'schiz', '8', '1.png']
# ['per31', 'schiz', '8', '2.png']
# ['per31', 'schiz', '8', '3.png']
# ['per31', 'schiz', '8', '4.png']
# ['per31', 'schiz', '8', '5.png']
# ['per31', 'schiz', '8', '6.png']
# ['per31', 'schiz', '8', '7.png']
# ['per31', 'schiz', '8', '8.png']
# ['per31', 'schiz', '8', '9.png']
# ['per31', 'schiz', '8', '10.png']
# ['per31', 'schiz', '8', '11.png']
# ['per31', 'schiz', '8', '12.png']
# ['per31', 'schiz', '8', '13.png']
# ['per31', 'schiz', '8', '14.png']
# ['per31', 'schiz', '9', '1.png']
# ['per31', 'schiz', '9', '2.png']
# ['per31', 'schiz', '9', '3.png']
# ['per31', 'schiz', '9', '4.png']
# ['per31', 'schiz', '9', '5.png']
# ['per31', 'schiz', '9', '6.png']
# ['per31', 'schiz', '9', '7.png']
# ['per31', 'schiz', '9', '8.png']
# ['per31', 'schiz', '9', '9.png']
# ['per31', 'schiz', '9', '10.png']
# ['per31', 'schiz', '9', '11.png']
# ['per31', 'schiz', '9', '12.png']
# ['per31', 'schiz', '9', '13.png']
# ['per31', 'schiz', '9', '14.png']
# ['per31', 'schiz', '10', '1.png']
# ['per31', 'schiz', '10', '2.png']
# ['per31', 'schiz', '10', '3.png']
# ['per31', 'schiz', '10', '4.png']
# ['per31', 'schiz', '10', '5.png']
# ['per31', 'schiz', '10', '6.png']
# ['per31', 'schiz', '10', '7.png']
# ['per31', 'schiz', '10', '8.png']
# ['per31', 'schiz', '10', '9.png']
# ['per31', 'schiz', '10', '10.png']
# ['per31', 'schiz', '10', '11.png']
# ['per31', 'schiz', '10', '12.png']
# ['per31', 'schiz', '10', '13.png']
# ['per31', 'schiz', '10', '14.png']
# ['per31', 'schiz', '11', '1.png']
# ['per31', 'schiz', '11', '2.png']
# ['per31', 'schiz', '11', '3.png']
# ['per31', 'schiz', '11', '4.png']
# ['per31', 'schiz', '11', '5.png']
# ['per31', 'schiz', '11', '6.png']
# ['per31', 'schiz', '11', '7.png']
# ['per31', 'schiz', '11', '8.png']
# ['per31', 'schiz', '11', '9.png']
# ['per31', 'schiz', '11', '10.png']
# ['per31', 'schiz', '11', '11.png']
# ['per31', 'schiz', '11', '12.png']
# ['per31', 'schiz', '11', '13.png']
# ['per31', 'schiz', '11', '14.png']
# ['per31', 'schiz', '12', '1.png']
# ['per31', 'schiz', '12', '2.png']
# ['per31', 'schiz', '12', '3.png']
# ['per31', 'schiz', '12', '4.png']
# ['per31', 'schiz', '12', '5.png']
# ['per31', 'schiz', '12', '6.png']
# ['per31', 'schiz', '12', '7.png']
# ['per31', 'schiz', '12', '8.png']
# ['per31', 'schiz', '12', '9.png']
# ['per31', 'schiz', '12', '10.png']
# ['per31', 'schiz', '12', '11.png']
# ['per31', 'schiz', '12', '12.png']
# ['per31', 'schiz', '12', '13.png']
# ['per31', 'schiz', '12', '14.png']
# ['per31', 'schiz', '13', '1.png']
# ['per31', 'schiz', '13', '2.png']
# ['per31', 'schiz', '13', '3.png']
# ['per31', 'schiz', '13', '4.png']
# ['per31', 'schiz', '13', '5.png']
# ['per31', 'schiz', '13', '6.png']
# ['per31', 'schiz', '13', '7.png']
